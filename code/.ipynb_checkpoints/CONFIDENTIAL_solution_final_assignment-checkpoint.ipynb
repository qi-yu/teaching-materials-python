# %% [markdown]
# # Seminar *Python for Linguists*: Final Assignment
# # Sample Solution
# <font color="grey">Instructor: Qi Yu (University of Konstanz)  |  ZHAW, March 03-04, 2022</font>

# %% [markdown]
# ## General Information
#
# This assignment consists of 4 tasks. In the tasks, you will work with various basic NLP tasks that researchers on NLP and computational linguistics often need to deal with. Please follow the guideline below to complete the assignment, and do all your implementation in this notebook.
#
# For passing the seminar and getting credits, you should have at least **50** of the 100 points.
#
# **Rules of Submission:**
# 1. When submitting your assignment, please rename the notebook with the following format: ```Lastname_Firstname.ipynb```
#
#     E.g., A person named Jane Smith would name her submission as ```Smith_Jane.ipynb```
#
#
# 2. Please submit the assignment **via E-mail to ```qi.yu@uni-konstanz.de```** by **March 31, 2022, 00:00**.

# %% [markdown]
# ## Guideline

# %% [markdown]
# In this assignment, you will work with the file ```peterpan_cleaned.txt``` which you have already created in the exercise ```exercise_regex_fileIO.ipynb```. If you still do not have this file, please re-run the Notebook ```solution_regex_fileIO.ipynb``` to generate one.

# %% [markdown]
# ## Task 1: Text Preprocessing

# %% [markdown]
# 1. Please read in the text ```peterpan_cleaned.txt```. You should read in the text as one chunk (**not** line by line). <font color="blue">(2 points)</font>

# %%
# ADD YOUR CODE HERE. Please feel free to split your code to multiple cells when necessary.

f = open('peterpan_cleaned.txt','r')
text = f.read()
f.close()

text
# Out:
# 'All children, except one, grow up. They soon know that they will grow\nup, and the way Wendy knew was this. One day when she was two years old\nshe was playing in a garden, and she plucked another flower and ran\nwith it to her mother. I suppose she must have looked rather\ndelightful, for Mrs. Darling put her hand to her heart and cried, "Oh,\nwhy can\'t you remain like this for ever!" This was all that passed\nbetween them on the subject, but henceforth Wendy knew that she must\ngrow up. You always know after you are two. Two is the beginning of the\nend.\nOf course they lived at 14, and until Wendy came her mother was the\nchief one. She was a lovely lady, with a romantic mind and such a sweet\nmocking mouth. Her romantic mind was like the tiny boxes, one within\nthe other, that come from the puzzling East, however many you discover\nthere is always one more; and her sweet mocking mouth had one kiss on\nit that Wendy could never get, though there it was, perfectly\nconspicuous in the right-hand corner.\nThe way Mr. Darling won her was this: the many gentlemen who had been\nboys when she was a girl discovered simultaneously that they loved her,\nand they all ran to her house to propose to her except Mr. Darling, who\ntook a cab and nipped in first, and so he got her. He got all of her,\nexcept the innermost box and the kiss. He never knew about the box, and\nin time he gave up trying for the kiss. Wendy thought Napoleon could\nhave got it, but I can picture him trying, and then going off in a\npassion, slamming the door.\nMr. Darling used to boast to Wendy that her mother not only loved him\nbut respected him. He was one of those deep ones who know about stocks\nand shares. Of course no one really knows, but he quite seemed to know,\nand he often said stocks were up and shares were down in a way that\nwould have made any woman respect him.\nMrs. Darling was married in white, and at first she kept the books\nperfectly, almost gleefully, as if it were a game, not so much as a\nBrussels sprout was missing; but by and by whole cauliflowers dropped\nout, and instead of them there were pictures of babies without faces.\nShe drew them when she should have been totting up. They were Mrs.\nDarling\'s guesses.\nWendy came first, then John, then Michael.\nFor a week or two after Wendy came it was doubtful whether they would\nbe able to keep her, as she was another mouth to feed. Mr. Darling was\nfrightfully proud of her, but he was very honourable, and he sat on the\nedge of Mrs. Darling\'s bed, holding her hand and calculating expenses,\nwhile she looked at him imploringly. She wanted to risk it, come what\nmight, but that was not his way; his way was with a pencil and a piece\nof paper, and if she confused him with suggestions he had to begin at\nthe beginning again.\n"Now don\'t interrupt," he would beg of her.\n"I have one pound seventeen here, and two and six at the office; I can\ncut off my coffee at the office, say ten shillings, making two nine and\nsix, with your eighteen and three makes three nine seven, with five\nnaught naught in my cheque-book makes eight nine seven—who is that\nmoving?—eight nine seven, dot and carry seven—don\'t speak, my own—and\nthe pound you lent to that man who came to the door—quiet, child—dot\nand carry child—there, you\'ve done it!—did I say nine nine seven? yes,\nI said nine nine seven; the question is, can we try it for a year on\nnine nine seven?"\n"Of course we can, George," she cried. But she was prejudiced in\nWendy\'s favour, and he was really the grander character of the two.\n"Remember mumps," he warned her almost threateningly, and off he went\nagain. "Mumps one pound, that is what I have put down, but I daresay it\nwill be more like thirty shillings—don\'t speak—measles one five, German\nmeasles half a guinea, makes two fifteen six—don\'t waggle your\nfinger—whooping-cough, say fifteen shillings"—and so on it went, and it\nadded up differently each time; but at last Wendy just got thro ...

# %% [markdown]
# 2. Please use NLTK to tokenize the text into words. <font color="blue">(3 points)</font>

# %%
# ADD YOUR CODE HERE. Please feel free to split your code to multiple cells when necessary.

from nltk.tokenize import word_tokenize

tokenized = word_tokenize(text)
tokenized
# Out:
# ['All',
#  'children',
#  ',',
#  'except',
#  'one',
#  ',',
#  'grow',
#  'up',
#  '.',
#  'They',
#  'soon',
#  'know',
#  'that',
#  'they',
#  'will',
#  'grow',
#  'up',
#  ',',
#  'and',
#  'the',
#  'way',
#  'Wendy',
#  'knew',
#  'was',
#  'this',
#  '.',
#  'One',
#  'day',
#  'when',
#  'she',
#  'was',
#  'two',
#  'years',
#  'old',
#  'she',
#  'was',
#  'playing',
#  'in',
#  'a',
#  'garden',
#  ',',
#  'and',
#  'she',
#  'plucked',
#  'another',
#  'flower',
#  'and',
#  'ran',
#  'with',
#  'it',
#  'to',
#  'her',
#  'mother',
#  '.',
#  'I',
#  'suppose',
#  'she',
#  'must',
#  'have',
#  'looked',
#  'rather',
#  'delightful',
#  ',',
#  'for',
#  'Mrs',
#  '.',
#  'Darling',
#  'put',
#  'her',
#  'hand',
#  'to',
#  'her',
#  'heart',
#  'and',
#  'cried',
#  ',',
#  '``',
#  'Oh',
#  ',',
#  'why',
#  'ca',
#  "n't",
#  'you',
#  'remain',
#  'like',
#  'this',
#  'for',
#  'ever',
#  '!',
#  "''",
#  'This',
#  'was',
#  'all',
#  'that',
#  'passed',
#  'between',
#  'them',
#  'on',
#  'the',
#  'subject',
#  ',',
#  'but',
#  'henceforth',
#  'Wendy',
#  'knew',
#  'that',
#  'she',
#  'must',
#  'grow',
#  'up',
#  '.',
#  'You',
#  'always',
#  'know',
#  'after',
#  'you',
#  'are',
#  'two',
#  '.',
#  'Two',
#  'is',
#  'the',
#  'beginning',
#  'of',
#  'the',
#  'end',
#  '.',
#  'Of',
#  'course',
#  'they',
#  'lived',
#  'at',
#  '14',
#  ',',
#  'and',
#  'until',
#  'Wendy',
#  'came',
#  'her',
#  'mother',
#  'was',
#  'the',
#  'chief',
#  'one',
#  '.',
#  'She',
#  'was',
#  'a',
#  'lovely',
#  'lady',
#  ',',
#  'with',
#  'a',
#  'romantic',
#  'mind',
#  'and',
#  'such',
#  'a',
#  'sweet',
#  'mocking',
#  'mouth',
#  '.',
#  'Her',
#  'romantic',
#  'mind',
#  'was',
#  'like',
#  'the',
#  'tiny',
#  'boxes',
#  ',',
#  'one',
#  'within',
#  'the',
#  'other',
#  ',',
#  'that',
#  'come',
#  'from',
#  'the',
#  'puzzling',
#  'East',
#  ',',
#  'however',
#  'many',
#  'you',
#  'discover',
#  'there',
#  'is',
#  'always',
#  'one',
#  'more',
#  ';',
#  'and',
#  'her',
#  'sweet',
#  'mocking',
#  'mouth',
#  'had',
#  'one',
#  'kiss',
#  'on',
#  'it',
#  'that',
#  'Wendy',
#  'could',
#  'never',
#  'get',
#  ',',
#  'though',
#  'there',
#  'it',
#  'was',
#  ',',
#  'perfectly',
#  'conspicuous',
#  'in',
#  'the',
#  'right-hand',
#  'corner',
#  '.',
#  'The',
#  'way',
#  'Mr',
#  '.',
#  'Darling',
#  'won',
#  'her',
#  'was',
#  'this',
#  ':',
#  'the',
#  'many',
#  'gentlemen',
#  'who',
#  'had',
#  'been',
#  'boys',
#  'when',
#  'she',
#  'was',
#  'a',
#  'girl',
#  'discovered',
#  'simultaneously',
#  'that',
#  'they',
#  'loved',
#  'her',
#  ',',
#  'and',
#  'they',
#  'all',
#  'ran',
#  'to',
#  'her',
#  'house',
#  'to',
#  'propose',
#  'to',
#  'her',
#  'except',
#  'Mr',
#  '.',
#  'Darling',
#  ',',
#  'who',
#  'took',
#  'a',
#  'cab',
#  'and',
#  'nipped',
#  'in',
#  'first',
#  ',',
#  'and',
#  'so',
#  'he',
#  'got',
#  'her',
#  '.',
#  'He',
#  'got',
#  'all',
#  'of',
#  'her',
#  ',',
#  'except',
#  'the',
#  'innermost',
#  'box',
#  'and',
#  'the',
#  'kiss',
#  '.',
#  'He',
#  'never',
#  'knew',
#  'about',
#  'the',
#  'box',
#  ',',
#  'and',
#  'in',
#  'time',
#  'he',
#  'gave',
#  'up',
#  'trying',
#  'for',
#  'the',
#  'kiss',
#  '.',
#  'Wendy',
#  'thought',
#  'Napoleon',
#  'could',
#  'have',
#  'got',
#  'it',
#  ',',
#  'but',
#  'I',
#  'can',
#  'picture',
#  'him',
#  'trying',
#  ',',
#  'and',
#  'then',
#  'going',
#  'off',
#  'in',
#  'a',
#  'passion',
#  ',',
#  'slamming',
#  'the',
#  'door',
#  '.',
#  'Mr',
#  '.',
#  'Darling',
#  'used',
#  'to',
#  'boast',
#  'to',
#  'Wendy',
#  'that',
#  'her',
#  'mother',
#  'not',
#  'only',
#  'loved',
#  'him',
#  'but',
#  'respected',
#  'him',
#  '.',
#  'He',
#  'was',
#  'one',
#  'of',
#  'those',
#  'deep',
#  'ones',
#  'who',
#  'know',
#  'about',
#  'stocks',
#  'and',
#  'shares',
#  '.',
#  'Of',
#  'course',
#  'no',
#  'one',
#  'really',
#  'knows',
#  ',',
#  'but',
#  'he',
#  'quite',
#  'seemed',
#  'to',
#  'know',
#  ',',
#  'and',
#  'he',
#  'often',
#  'said',
#  'stocks',
#  'were',
#  'up',
#  'and',
#  'shares',
#  'were',
#  'down',
#  'in',
#  'a',
#  'way',
#  'that',
#  'would',
#  'have',
#  'made',
#  'any',
#  'woman',
#  'respect',
#  'him',
#  '.',
#  'Mrs',
#  '.',
#  'Darling',
#  'was',
#  'married',
#  'in',
#  'white',
#  ',',
#  'and',
#  'at',
#  'first',
#  'she',
#  'kept',
#  'the',
#  'books',
#  'perfectly',
#  ',',
#  'almost',
#  'gleefully',
#  ',',
#  'as',
#  'if',
#  'it',
#  'were',
#  'a',
#  'game',
#  ',',
#  'not',
#  'so',
#  'much',
#  'as',
#  'a',
#  'Brussels',
#  'sprout',
#  'was',
#  'missing',
#  ';',
#  'but',
#  'by',
#  'and',
#  'by',
#  'whole',
#  'cauliflowers',
#  'dropped',
#  'out',
#  ',',
#  'and',
#  'instead',
#  'of',
#  'them',
#  'there',
#  'were',
#  'pictures',
#  'of',
#  'babies',
#  'without',
#  'faces',
#  '.',
#  'She',
#  'drew',
#  'them',
#  'when',
#  'she',
#  'should',
#  'have',
#  'been',
#  'totting',
#  'up',
#  '.',
#  'They',
#  'were',
#  'Mrs',
#  '.',
#  'Darling',
#  "'s",
#  'guesses',
#  '.',
#  'Wendy',
#  'came',
#  'first',
#  ',',
#  'then',
#  'John',
#  ',',
#  'then',
#  'Michael',
#  '.',
#  'For',
#  'a',
#  'week',
#  'or',
#  'two',
#  'after',
#  'Wendy',
#  'came',
#  'it',
#  'was',
#  'doubtful',
#  'whether',
#  'they',
#  'would',
#  'be',
#  'able',
#  'to',
#  'keep',
#  'her',
#  ',',
#  'as',
#  'she',
#  'was',
#  'another',
#  'mouth',
#  'to',
#  'feed',
#  '.',
#  'Mr',
#  '.',
#  'Darling',
#  'was',
#  'frightfully',
#  'proud',
#  'of',
#  'her',
#  ',',
#  'but',
#  'he',
#  'was',
#  'very',
#  'honourable',
#  ',',
#  'and',
#  'he',
#  'sat',
#  'on',
#  'the',
#  'edge',
#  'of',
#  'Mrs',
#  '.',
#  'Darling',
#  "'s",
#  'bed',
#  ',',
#  'holding',
#  'her',
#  'hand',
#  'and',
#  'calculating',
#  'expenses',
#  ',',
#  'while',
#  'she',
#  'looked',
#  'at',
#  'him',
#  'imploringly',
#  '.',
#  'She',
#  'wanted',
#  'to',
#  'risk',
#  'it',
#  ',',
#  'come',
#  'what',
#  'might',
#  ',',
#  'but',
#  'that',
#  'was',
#  'not',
#  'his',
#  'way',
#  ';',
#  'his',
#  'way',
#  'was',
#  'with',
#  'a',
#  'pencil',
#  'and',
#  'a',
#  'piece',
#  'of',
#  'paper',
#  ',',
#  'and',
#  'if',
#  'she',
#  'confused',
#  'him',
#  'with',
#  'suggestions',
#  'he',
#  'had',
#  'to',
#  'begin',
#  'at',
#  'the',
#  'beginning',
#  'again',
#  '.',
#  '``',
#  'Now',
#  'do',
#  "n't",
#  'interrupt',
#  ',',
#  "''",
#  'he',
#  'would',
#  'beg',
#  'of',
#  'her',
#  '.',
#  '``',
#  'I',
#  'have',
#  'one',
#  'pound',
#  'seventeen',
#  'here',
#  ',',
#  'and',
#  'two',
#  'and',
#  'six',
#  'at',
#  'the',
#  'office',
#  ';',
#  'I',
#  'can',
#  'cut',
#  'off',
#  'my',
#  'coffee',
#  'at',
#  'the',
#  'office',
#  ',',
#  'say',
#  'ten',
#  'shillings',
#  ',',
#  'making',
#  'two',
#  'nine',
#  'and',
#  'six',
#  ',',
#  'with',
#  'your',
#  'eighteen',
#  'and',
#  'three',
#  'makes',
#  'three',
#  'nine',
#  'seven',
#  ',',
#  'with',
#  'five',
#  'naught',
#  'naught',
#  'in',
#  'my',
#  'cheque-book',
#  'makes',
#  'eight',
#  'nine',
#  'seven—who',
#  'is',
#  'that',
#  'moving',
#  '?',
#  '—eight',
#  'nine',
#  'seven',
#  ',',
#  'dot',
#  'and',
#  'carry',
#  'seven—do',
#  "n't",
#  'speak',
#  ',',
#  'my',
#  'own—and',
#  'the',
#  'pound',
#  'you',
#  'lent',
#  'to',
#  'that',
#  'man',
#  'who',
#  'came',
#  'to',
#  'the',
#  'door—quiet',
#  ',',
#  'child—dot',
#  'and',
#  'carry',
#  'child—there',
#  ',',
#  'you',
#  "'ve",
#  'done',
#  'it',
#  '!',
#  '—did',
#  'I',
#  'say',
#  'nine',
#  'nine',
#  'seven',
#  '?',
#  'yes',
#  ',',
#  'I',
#  'said',
#  'nine',
#  'nine',
#  'seven',
#  ';',
#  'the',
#  'question',
#  'is',
#  ',',
#  'can',
#  'we',
#  'try',
#  'it',
#  'for',
#  'a',
#  'year',
#  'on',
#  'nine',
#  'nine',
#  'seven',
#  '?',
#  "''",
#  '``',
#  'Of',
#  'course',
#  'we',
#  'can',
#  ',',
#  'George',
#  ',',
#  "''",
#  'she',
#  'cried',
#  '.',
#  'But',
#  'she',
#  'was',
#  'prejudiced',
#  'in',
#  'Wendy',
#  "'s",
#  'favour',
#  ',',
#  'and',
#  'he',
#  'was',
#  'really',
#  'the',
#  'grander',
#  'character',
#  'of',
#  'the',
#  'two',
#  '.',
#  '``',
#  'Remember',
#  'mumps',
#  ',',
#  "''",
#  'he',
#  'warned',
#  'her',
#  'almost',
#  'threateningly',
#  ',',
#  'and',
#  'off',
#  'he',
#  'went',
#  'again',
#  '.',
#  '``',
#  'Mumps',
#  'one',
#  'pound',
#  ',',
#  'that',
#  'is',
#  'what',
#  'I',
#  'have',
#  'put',
#  'down',
#  ',',
#  'but',
#  'I',
#  'daresay',
#  'it',
#  'will',
#  'be',
#  'more',
#  'like',
#  'thirty',
#  'shillings—do',
#  "n't",
#  'speak—measles',
#  'one',
#  'five',
#  ',',
#  'German',
#  'measles',
#  'half',
#  'a',
#  'guinea',
#  ',',
#  'makes',
#  'two',
#  'fifteen',
#  'six—do',
#  "n't",
#  'waggle',
#  'your',
#  'finger—whooping-cough',
#  ',',
#  'say',
#  'fifteen',
#  'shillings',
#  "''",
#  '—and',
#  'so',
#  'on',
#  'it',
#  'went',
#  ',',
#  'and',
#  'it',
#  'added',
#  'up',
#  'differently',
#  'each',
#  'time',
#  ';',
#  'but',
#  'at',
#  'last',
#  'Wendy',
#  'just',
#  'got',
#  'through',
#  ',',
#  'with',
#  'mumps',
#  'reduced',
#  'to',
#  'twelve',
#  'six',
#  ',',
#  'and',
#  'the',
#  'two',
#  'kinds',
#  'of',
#  'measles',
#  'treated',
#  'as',
#  'one',
#  '.',
#  'There',
#  'was',
#  'the',
#  'same',
#  'excitement',
#  'over',
#  'John',
#  ',',
#  'and',
#  'Michael',
#  'had',
#  'even',
#  'a',
#  'narrower',
#  'squeak',
#  ';',
#  'but',
#  'both',
#  'were',
#  'kept',
#  ',',
#  'and',
#  'soon',
#  ',',
#  'you',
#  'might',
#  'have',
#  'seen',
#  'the',
#  'three',
#  'of',
#  'them',
#  'going',
#  'in',
#  'a',
#  'row',
#  'to',
#  'Miss',
#  'Fulsom',
#  "'s",
#  'Kindergarten',
#  'school',
#  ',',
#  'accompanied',
#  'by',
#  'their',
#  'nurse',
#  '.',
#  'Mrs',
#  '.',
#  'Darling',
#  'loved',
#  'to',
#  'have',
#  'everything',
#  'just',
#  'so',
#  ',',
#  'and',
#  'Mr',
#  '.',
#  'Darling',
#  'had',
#  'a',
#  'passion',
#  'for',
#  'being',
#  'exactly',
#  'like',
#  'his',
#  'neighbours',
#  ';',
#  'so',
#  ',',
#  'of',
#  'course',
#  ',',
#  'they',
#  'had',
#  'a',
#  'nurse',
#  '.',
#  'As',
#  'they',
#  'were',
#  'poor',
#  ',',
#  'owing',
#  'to',
#  'the',
#  'amount',
#  'of',
#  'milk',
#  'the',
#  'children',
#  'drank',
#  ',',
#  'this',
#  'nurse',
#  'was',
#  'a',
#  'prim',
#  'Newfoundland',
#  'dog',
#  ',',
#  'called',
#  'Nana',
#  ',',
#  'who',
#  'had',
#  'belonged',
#  ...]

# %% [markdown]
# ## Task 2: Named Entities

# %% [markdown]
# In computational linguistic researches, researchers are often interested in checking what the most frequent occurring **named entities** in a text are. Roughly speaking, a *named entity* is anything that can be referred to as a proper name, e.g., ```Peter```, ```Switzerland```, ```United Airlines```.
#
# We can approximate the search of named entities by firstly POS-tagging the text and then searching for tokens bearing the POS-tags ```NNP``` or ```NNPS``` - Please check the [*Penn Treebank Tagset*](https://www.cs.upc.edu/~nlp/SVMTool/PennTreebank.html) to find out what they stand for.
#
# (**NB:** There are named entities which consist of more than one tokens, such as the example ```United Airlines``` above. For the purpose of simplicity, we will just ignore such cases.)
#
# Now, please follow the steps below to find out the most frequent named entities in ```peterpan_cleaned.txt```:

# %% [markdown]
# 1. Please use NLTK to POS-tag the already tokenized text resulted from Task 1. <font color="blue">(7 points)</font>

# %%
# ADD YOUR CODE HERE. Please feel free to split your code to multiple cells when necessary.

from nltk import pos_tag

pos_tagged = pos_tag(tokenized)
pos_tagged
# Out:
# [('All', 'DT'),
#  ('children', 'NNS'),
#  (',', ','),
#  ('except', 'IN'),
#  ('one', 'CD'),
#  (',', ','),
#  ('grow', 'VB'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('soon', 'RB'),
#  ('know', 'VBP'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('will', 'MD'),
#  ('grow', 'VB'),
#  ('up', 'RP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('Wendy', 'NNP'),
#  ('knew', 'VBD'),
#  ('was', 'VBD'),
#  ('this', 'DT'),
#  ('.', '.'),
#  ('One', 'CD'),
#  ('day', 'NN'),
#  ('when', 'WRB'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  ('old', 'JJ'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('playing', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('garden', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('plucked', 'VBD'),
#  ('another', 'DT'),
#  ('flower', 'NN'),
#  ('and', 'CC'),
#  ('ran', 'NN'),
#  ('with', 'IN'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('mother', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('suppose', 'VBP'),
#  ('she', 'PRP'),
#  ('must', 'MD'),
#  ('have', 'VB'),
#  ('looked', 'VBN'),
#  ('rather', 'RB'),
#  ('delightful', 'JJ'),
#  (',', ','),
#  ('for', 'IN'),
#  ('Mrs', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'VBG'),
#  ('put', 'VBD'),
#  ('her', 'PRP$'),
#  ('hand', 'NN'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('heart', 'NN'),
#  ('and', 'CC'),
#  ('cried', 'VBD'),
#  (',', ','),
#  ('``', '``'),
#  ('Oh', 'UH'),
#  (',', ','),
#  ('why', 'WRB'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('you', 'PRP'),
#  ('remain', 'VBP'),
#  ('like', 'IN'),
#  ('this', 'DT'),
#  ('for', 'IN'),
#  ('ever', 'RB'),
#  ('!', '.'),
#  ("''", "''"),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('all', 'DT'),
#  ('that', 'IN'),
#  ('passed', 'VBD'),
#  ('between', 'IN'),
#  ('them', 'PRP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('subject', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('henceforth', 'JJ'),
#  ('Wendy', 'NNP'),
#  ('knew', 'VBD'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('must', 'MD'),
#  ('grow', 'VB'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('always', 'RB'),
#  ('know', 'VBP'),
#  ('after', 'IN'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('two', 'CD'),
#  ('.', '.'),
#  ('Two', 'CD'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('beginning', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('.', '.'),
#  ('Of', 'IN'),
#  ('course', 'NN'),
#  ('they', 'PRP'),
#  ('lived', 'VBD'),
#  ('at', 'IN'),
#  ('14', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('until', 'IN'),
#  ('Wendy', 'NNP'),
#  ('came', 'VBD'),
#  ('her', 'PRP$'),
#  ('mother', 'NN'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('chief', 'JJ'),
#  ('one', 'NN'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('lovely', 'JJ'),
#  ('lady', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('romantic', 'JJ'),
#  ('mind', 'NN'),
#  ('and', 'CC'),
#  ('such', 'PDT'),
#  ('a', 'DT'),
#  ('sweet', 'JJ'),
#  ('mocking', 'NN'),
#  ('mouth', 'NN'),
#  ('.', '.'),
#  ('Her', 'PRP$'),
#  ('romantic', 'JJ'),
#  ('mind', 'NN'),
#  ('was', 'VBD'),
#  ('like', 'IN'),
#  ('the', 'DT'),
#  ('tiny', 'JJ'),
#  ('boxes', 'NNS'),
#  (',', ','),
#  ('one', 'CD'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  (',', ','),
#  ('that', 'IN'),
#  ('come', 'VBP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('puzzling', 'VBG'),
#  ('East', 'NNP'),
#  (',', ','),
#  ('however', 'RB'),
#  ('many', 'JJ'),
#  ('you', 'PRP'),
#  ('discover', 'VBP'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('always', 'RB'),
#  ('one', 'CD'),
#  ('more', 'JJR'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('her', 'PRP$'),
#  ('sweet', 'JJ'),
#  ('mocking', 'NN'),
#  ('mouth', 'NN'),
#  ('had', 'VBD'),
#  ('one', 'CD'),
#  ('kiss', 'NN'),
#  ('on', 'IN'),
#  ('it', 'PRP'),
#  ('that', 'IN'),
#  ('Wendy', 'NNP'),
#  ('could', 'MD'),
#  ('never', 'RB'),
#  ('get', 'VB'),
#  (',', ','),
#  ('though', 'IN'),
#  ('there', 'EX'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  (',', ','),
#  ('perfectly', 'RB'),
#  ('conspicuous', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('right-hand', 'NN'),
#  ('corner', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('way', 'NN'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'VBG'),
#  ('won', 'VBD'),
#  ('her', 'PRP$'),
#  ('was', 'VBD'),
#  ('this', 'DT'),
#  (':', ':'),
#  ('the', 'DT'),
#  ('many', 'JJ'),
#  ('gentlemen', 'NNS'),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('boys', 'VBN'),
#  ('when', 'WRB'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('girl', 'NN'),
#  ('discovered', 'VBD'),
#  ('simultaneously', 'RB'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('loved', 'VBD'),
#  ('her', 'PRP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('all', 'DT'),
#  ('ran', 'VBD'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('house', 'NN'),
#  ('to', 'TO'),
#  ('propose', 'VB'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('except', 'IN'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('took', 'VBD'),
#  ('a', 'DT'),
#  ('cab', 'NN'),
#  ('and', 'CC'),
#  ('nipped', 'VBD'),
#  ('in', 'IN'),
#  ('first', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('so', 'RB'),
#  ('he', 'PRP'),
#  ('got', 'VBD'),
#  ('her', 'PRP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('got', 'VBD'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('her', 'PRP'),
#  (',', ','),
#  ('except', 'IN'),
#  ('the', 'DT'),
#  ('innermost', 'NN'),
#  ('box', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('kiss', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('never', 'RB'),
#  ('knew', 'VBD'),
#  ('about', 'IN'),
#  ('the', 'DT'),
#  ('box', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('time', 'NN'),
#  ('he', 'PRP'),
#  ('gave', 'VBD'),
#  ('up', 'RP'),
#  ('trying', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('kiss', 'NN'),
#  ('.', '.'),
#  ('Wendy', 'NNP'),
#  ('thought', 'VBD'),
#  ('Napoleon', 'NNP'),
#  ('could', 'MD'),
#  ('have', 'VB'),
#  ('got', 'VBD'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('picture', 'VB'),
#  ('him', 'PRP'),
#  ('trying', 'VBG'),
#  (',', ','),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('going', 'VBG'),
#  ('off', 'RP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('passion', 'NN'),
#  (',', ','),
#  ('slamming', 'VBG'),
#  ('the', 'DT'),
#  ('door', 'NN'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'VBG'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('boast', 'VB'),
#  ('to', 'TO'),
#  ('Wendy', 'NNP'),
#  ('that', 'IN'),
#  ('her', 'PRP$'),
#  ('mother', 'NN'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('loved', 'VBD'),
#  ('him', 'PRP'),
#  ('but', 'CC'),
#  ('respected', 'VBD'),
#  ('him', 'PRP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('was', 'VBD'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('deep', 'JJ'),
#  ('ones', 'NNS'),
#  ('who', 'WP'),
#  ('know', 'VBP'),
#  ('about', 'IN'),
#  ('stocks', 'NNS'),
#  ('and', 'CC'),
#  ('shares', 'NNS'),
#  ('.', '.'),
#  ('Of', 'IN'),
#  ('course', 'NN'),
#  ('no', 'DT'),
#  ('one', 'CD'),
#  ('really', 'RB'),
#  ('knows', 'VBZ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('he', 'PRP'),
#  ('quite', 'RB'),
#  ('seemed', 'VBD'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('often', 'RB'),
#  ('said', 'VBD'),
#  ('stocks', 'NNS'),
#  ('were', 'VBD'),
#  ('up', 'RB'),
#  ('and', 'CC'),
#  ('shares', 'NNS'),
#  ('were', 'VBD'),
#  ('down', 'RB'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('way', 'NN'),
#  ('that', 'WDT'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('made', 'VBN'),
#  ('any', 'DT'),
#  ('woman', 'NN'),
#  ('respect', 'NN'),
#  ('him', 'PRP'),
#  ('.', '.'),
#  ('Mrs', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  ('was', 'VBD'),
#  ('married', 'VBN'),
#  ('in', 'IN'),
#  ('white', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('at', 'IN'),
#  ('first', 'JJ'),
#  ('she', 'PRP'),
#  ('kept', 'VBD'),
#  ('the', 'DT'),
#  ('books', 'NNS'),
#  ('perfectly', 'RB'),
#  (',', ','),
#  ('almost', 'RB'),
#  ('gleefully', 'RB'),
#  (',', ','),
#  ('as', 'IN'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('were', 'VBD'),
#  ('a', 'DT'),
#  ('game', 'NN'),
#  (',', ','),
#  ('not', 'RB'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('Brussels', 'NNP'),
#  ('sprout', 'NN'),
#  ('was', 'VBD'),
#  ('missing', 'VBG'),
#  (';', ':'),
#  ('but', 'CC'),
#  ('by', 'IN'),
#  ('and', 'CC'),
#  ('by', 'IN'),
#  ('whole', 'JJ'),
#  ('cauliflowers', 'NNS'),
#  ('dropped', 'VBD'),
#  ('out', 'RP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('instead', 'RB'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('there', 'EX'),
#  ('were', 'VBD'),
#  ('pictures', 'NNS'),
#  ('of', 'IN'),
#  ('babies', 'NNS'),
#  ('without', 'IN'),
#  ('faces', 'VBZ'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('drew', 'VBD'),
#  ('them', 'PRP'),
#  ('when', 'WRB'),
#  ('she', 'PRP'),
#  ('should', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('totting', 'VBG'),
#  ('up', 'RP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('were', 'VBD'),
#  ('Mrs', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  ("'s", 'POS'),
#  ('guesses', 'NNS'),
#  ('.', '.'),
#  ('Wendy', 'NNP'),
#  ('came', 'VBD'),
#  ('first', 'RB'),
#  (',', ','),
#  ('then', 'RB'),
#  ('John', 'NNP'),
#  (',', ','),
#  ('then', 'RB'),
#  ('Michael', 'NNP'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('a', 'DT'),
#  ('week', 'NN'),
#  ('or', 'CC'),
#  ('two', 'CD'),
#  ('after', 'IN'),
#  ('Wendy', 'WDT'),
#  ('came', 'VBD'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('doubtful', 'JJ'),
#  ('whether', 'IN'),
#  ('they', 'PRP'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('keep', 'VB'),
#  ('her', 'PRP'),
#  (',', ','),
#  ('as', 'IN'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('another', 'DT'),
#  ('mouth', 'NN'),
#  ('to', 'TO'),
#  ('feed', 'VB'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  ('was', 'VBD'),
#  ('frightfully', 'RB'),
#  ('proud', 'JJ'),
#  ('of', 'IN'),
#  ('her', 'PRP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('honourable', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('sat', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('edge', 'NN'),
#  ('of', 'IN'),
#  ('Mrs', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  ("'s", 'POS'),
#  ('bed', 'NN'),
#  (',', ','),
#  ('holding', 'VBG'),
#  ('her', 'PRP$'),
#  ('hand', 'NN'),
#  ('and', 'CC'),
#  ('calculating', 'NN'),
#  ('expenses', 'NNS'),
#  (',', ','),
#  ('while', 'IN'),
#  ('she', 'PRP'),
#  ('looked', 'VBD'),
#  ('at', 'IN'),
#  ('him', 'PRP'),
#  ('imploringly', 'RB'),
#  ('.', '.'),
#  ('She', 'PRP'),
#  ('wanted', 'VBD'),
#  ('to', 'TO'),
#  ('risk', 'VB'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('come', 'VB'),
#  ('what', 'WP'),
#  ('might', 'MD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('that', 'DT'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('his', 'PRP$'),
#  ('way', 'NN'),
#  (';', ':'),
#  ('his', 'PRP$'),
#  ('way', 'NN'),
#  ('was', 'VBD'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('pencil', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('piece', 'NN'),
#  ('of', 'IN'),
#  ('paper', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('if', 'IN'),
#  ('she', 'PRP'),
#  ('confused', 'VBD'),
#  ('him', 'PRP'),
#  ('with', 'IN'),
#  ('suggestions', 'NNS'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('begin', 'VB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('beginning', 'NN'),
#  ('again', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Now', 'RB'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('interrupt', 'VB'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('beg', 'VB'),
#  ('of', 'IN'),
#  ('her', 'PRP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('one', 'CD'),
#  ('pound', 'NN'),
#  ('seventeen', 'NN'),
#  ('here', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('two', 'CD'),
#  ('and', 'CC'),
#  ('six', 'CD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('office', 'NN'),
#  (';', ':'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('cut', 'VB'),
#  ('off', 'RP'),
#  ('my', 'PRP$'),
#  ('coffee', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('office', 'NN'),
#  (',', ','),
#  ('say', 'VBP'),
#  ('ten', 'JJ'),
#  ('shillings', 'NNS'),
#  (',', ','),
#  ('making', 'VBG'),
#  ('two', 'CD'),
#  ('nine', 'CD'),
#  ('and', 'CC'),
#  ('six', 'CD'),
#  (',', ','),
#  ('with', 'IN'),
#  ('your', 'PRP$'),
#  ('eighteen', 'NN'),
#  ('and', 'CC'),
#  ('three', 'CD'),
#  ('makes', 'VBZ'),
#  ('three', 'CD'),
#  ('nine', 'CD'),
#  ('seven', 'CD'),
#  (',', ','),
#  ('with', 'IN'),
#  ('five', 'CD'),
#  ('naught', 'JJ'),
#  ('naught', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('cheque-book', 'NN'),
#  ('makes', 'VBZ'),
#  ('eight', 'CD'),
#  ('nine', 'CD'),
#  ('seven—who', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('moving', 'VBG'),
#  ('?', '.'),
#  ('—eight', 'JJ'),
#  ('nine', 'CD'),
#  ('seven', 'CD'),
#  (',', ','),
#  ('dot', 'NNS'),
#  ('and', 'CC'),
#  ('carry', 'NN'),
#  ('seven—do', 'VBP'),
#  ("n't", 'RB'),
#  ('speak', 'VB'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('own—and', 'VBP'),
#  ('the', 'DT'),
#  ('pound', 'NN'),
#  ('you', 'PRP'),
#  ('lent', 'VBP'),
#  ('to', 'TO'),
#  ('that', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('came', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('door—quiet', 'NN'),
#  (',', ','),
#  ('child—dot', 'NN'),
#  ('and', 'CC'),
#  ('carry', 'NN'),
#  ('child—there', 'RB'),
#  (',', ','),
#  ('you', 'PRP'),
#  ("'ve", 'VBP'),
#  ('done', 'VBN'),
#  ('it', 'PRP'),
#  ('!', '.'),
#  ('—did', 'JJ'),
#  ('I', 'PRP'),
#  ('say', 'VBP'),
#  ('nine', 'CD'),
#  ('nine', 'CD'),
#  ('seven', 'CD'),
#  ('?', '.'),
#  ('yes', 'UH'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('said', 'VBD'),
#  ('nine', 'CD'),
#  ('nine', 'CD'),
#  ('seven', 'CD'),
#  (';', ':'),
#  ('the', 'DT'),
#  ('question', 'NN'),
#  ('is', 'VBZ'),
#  (',', ','),
#  ('can', 'MD'),
#  ('we', 'PRP'),
#  ('try', 'VB'),
#  ('it', 'PRP'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('on', 'IN'),
#  ('nine', 'CD'),
#  ('nine', 'CD'),
#  ('seven', 'CD'),
#  ('?', '.'),
#  ("''", "''"),
#  ('``', '``'),
#  ('Of', 'IN'),
#  ('course', 'NN'),
#  ('we', 'PRP'),
#  ('can', 'MD'),
#  (',', ','),
#  ('George', 'NNP'),
#  (',', ','),
#  ("''", "''"),
#  ('she', 'PRP'),
#  ('cried', 'VBD'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('prejudiced', 'VBN'),
#  ('in', 'IN'),
#  ('Wendy', 'NNP'),
#  ("'s", 'POS'),
#  ('favour', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('really', 'RB'),
#  ('the', 'DT'),
#  ('grander', 'NN'),
#  ('character', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Remember', 'NNP'),
#  ('mumps', 'NNS'),
#  (',', ','),
#  ("''", "''"),
#  ('he', 'PRP'),
#  ('warned', 'VBD'),
#  ('her', 'PRP'),
#  ('almost', 'RB'),
#  ('threateningly', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('off', 'IN'),
#  ('he', 'PRP'),
#  ('went', 'VBD'),
#  ('again', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Mumps', 'NNP'),
#  ('one', 'CD'),
#  ('pound', 'NN'),
#  (',', ','),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('what', 'WP'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('put', 'VBN'),
#  ('down', 'RP'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('daresay', 'VBP'),
#  ('it', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('more', 'RBR'),
#  ('like', 'IN'),
#  ('thirty', 'NN'),
#  ('shillings—do', 'VBP'),
#  ("n't", 'RB'),
#  ('speak—measles', 'VB'),
#  ('one', 'CD'),
#  ('five', 'CD'),
#  (',', ','),
#  ('German', 'JJ'),
#  ('measles', 'VBZ'),
#  ('half', 'PDT'),
#  ('a', 'DT'),
#  ('guinea', 'NN'),
#  (',', ','),
#  ('makes', 'VBZ'),
#  ('two', 'CD'),
#  ('fifteen', 'JJ'),
#  ('six—do', 'VBP'),
#  ("n't", 'RB'),
#  ('waggle', 'VB'),
#  ('your', 'PRP$'),
#  ('finger—whooping-cough', 'JJ'),
#  (',', ','),
#  ('say', 'VBP'),
#  ('fifteen', 'JJ'),
#  ('shillings', 'NNS'),
#  ("''", "''"),
#  ('—and', 'VBP'),
#  ('so', 'RB'),
#  ('on', 'IN'),
#  ('it', 'PRP'),
#  ('went', 'VBD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('added', 'VBD'),
#  ('up', 'RP'),
#  ('differently', 'RB'),
#  ('each', 'DT'),
#  ('time', 'NN'),
#  (';', ':'),
#  ('but', 'CC'),
#  ('at', 'IN'),
#  ('last', 'JJ'),
#  ('Wendy', 'NNP'),
#  ('just', 'RB'),
#  ('got', 'VBD'),
#  ('through', 'IN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('mumps', 'NNS'),
#  ('reduced', 'VBN'),
#  ('to', 'TO'),
#  ('twelve', 'VB'),
#  ('six', 'CD'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('kinds', 'NNS'),
#  ('of', 'IN'),
#  ('measles', 'NNS'),
#  ('treated', 'VBN'),
#  ('as', 'IN'),
#  ('one', 'CD'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('excitement', 'NN'),
#  ('over', 'IN'),
#  ('John', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Michael', 'NNP'),
#  ('had', 'VBD'),
#  ('even', 'RB'),
#  ('a', 'DT'),
#  ('narrower', 'JJR'),
#  ('squeak', 'NN'),
#  (';', ':'),
#  ('but', 'CC'),
#  ('both', 'DT'),
#  ('were', 'VBD'),
#  ('kept', 'VBN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('soon', 'RB'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('might', 'MD'),
#  ('have', 'VB'),
#  ('seen', 'VBN'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('going', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('row', 'NN'),
#  ('to', 'TO'),
#  ('Miss', 'NNP'),
#  ('Fulsom', 'NNP'),
#  ("'s", 'POS'),
#  ('Kindergarten', 'NNP'),
#  ('school', 'NN'),
#  (',', ','),
#  ('accompanied', 'VBN'),
#  ('by', 'IN'),
#  ('their', 'PRP$'),
#  ('nurse', 'NN'),
#  ('.', '.'),
#  ('Mrs', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'VBG'),
#  ('loved', 'VBN'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('everything', 'NN'),
#  ('just', 'RB'),
#  ('so', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('Mr', 'NNP'),
#  ('.', '.'),
#  ('Darling', 'NNP'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('passion', 'NN'),
#  ('for', 'IN'),
#  ('being', 'VBG'),
#  ('exactly', 'RB'),
#  ('like', 'IN'),
#  ('his', 'PRP$'),
#  ('neighbours', 'NNS'),
#  (';', ':'),
#  ('so', 'RB'),
#  (',', ','),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('nurse', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('poor', 'JJ'),
#  (',', ','),
#  ('owing', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('milk', 'NN'),
#  ('the', 'DT'),
#  ('children', 'NNS'),
#  ('drank', 'NN'),
#  (',', ','),
#  ('this', 'DT'),
#  ('nurse', 'NN'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('prim', 'JJ'),
#  ('Newfoundland', 'NNP'),
#  ('dog', 'NN'),
#  (',', ','),
#  ('called', 'VBN'),
#  ('Nana', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('belonged', 'VBN'),
#  ...]

# %% [markdown]
# 2. We can use a dictionary to record tokens that are POS-tagged as ```NNP``` or ```NNPS``` together with their respective frequencies (i.e., how many times they occur in ```peterpan_cleaned.txt```). To be exact, we can build a dictionary with such tokens as keys and their frequencies as values.
#
#     Please construct further on the dictionary ```ne_freq_dict``` given below, so that it has the following form at the end:
#
#     ```{'Wendy': 341, 'Peter': 394, 'Brussels': 1, ...}```
#     (which means: In the text, ```Wendy``` occurs 314 times in all, ```Peter``` occurs 394 times in all, ```Brussels``` occurs 1 time in all, etc.)
#
#     **Tips:** Recall that the value of a key can be overwritten, i.e., the values in a dictionary are modifiable (see ```data_types.ipynb```, Section 6). Thus, you can build the ```ne_freq_dict``` in the following way:
#     1. When a proper noun P1 is found in the text, and P1 already exists as a key in the dictionary, the value of P1 should increase by 1.
#     2. When a proper noun P2 is found in the text, but P2 still does not exist as a key in the dictionary, you should add a new item to the dictionary with P2 as key and 1 as value. This means: when P2 is found again in the text later, the procedure *A* will be carried out, as P2 now is already an existing key.
#
#
#
# **NB:** You will notice that some tokens, such as ```Oh``` or ```Mr```, are wrongly tagged by the POS-tagger of NLTK as proper nouns. Every POS-tagger will generate such mistakes. For the purpose of simplicity, please just ignore these mistakes and pretend that they are proper nouns.
#
# <font color="blue">(20 points)</font>

# %%
ne_freq_dict = {}

# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

for token, tag in pos_tagged:
    if tag == "NNP" or tag == "NNPS":
        if token not in ne_freq_dict:
            ne_freq_dict[token] = 1
        else:
            ne_freq_dict[token] += 1
            
ne_freq_dict
# Out:
# {'Wendy': 347,
#  'Mrs': 72,
#  'East': 1,
#  'Mr': 39,
#  'Darling': 60,
#  'Napoleon': 1,
#  'Brussels': 1,
#  'John': 132,
#  'Michael': 109,
#  'George': 20,
#  'Remember': 1,
#  'Mumps': 1,
#  'Miss': 2,
#  'Fulsom': 2,
#  'Kindergarten': 1,
#  'Newfoundland': 1,
#  'Nana': 64,
#  'Darlings': 1,
#  'Kensington': 3,
#  'Gardens': 3,
#  "John's": 1,
#  'Liza': 10,
#  'Peter': 394,
#  'Pan': 24,
#  'Neverland': 22,
#  'Neverlands': 2,
#  'Oh': 20,
#  'Mark': 1,
#  'Children': 2,
#  'Were': 1,
#  'England': 3,
#  'Certainly': 1,
#  'Again': 5,
#  'Friday': 4,
#  'Mea': 1,
#  'names': 1,
#  "Wendy's": 3,
#  'Boy': 7,
#  'Mr.': 7,
#  'O': 18,
#  'No': 14,
#  'Wo': 1,
#  'Mother': 9,
#  '‘': 8,
#  'Thank': 2,
#  'Ever': 1,
#  'Father': 10,
#  'Come': 4,
#  'Neither': 1,
#  'Well': 9,
#  'Are': 8,
#  'Stop': 1,
#  'I—I': 1,
#  'Look': 3,
#  'Coddle': 1,
#  'Somehow': 1,
#  'Bring': 2,
#  'Alas': 3,
#  'Nothing': 1,
#  'Milky': 1,
#  'Way': 1,
#  'COME': 2,
#  'AWAY': 2,
#  'Tinker': 29,
#  'Bell': 29,
#  'Tink': 47,
#  'Moira': 2,
#  'Angela': 2,
#  'Kings': 1,
#  'So': 2,
#  'Ought': 2,
#  "I'm": 1,
#  'How': 4,
#  'Which': 5,
#  'Cinderella': 4,
#  'Mermaids': 3,
#  'Oo': 1,
#  'Wake': 1,
#  'Hallo': 1,
#  'Christmas': 1,
#  'A': 2,
#  'Z': 1,
#  'Heavenly': 1,
#  'Pirates': 1,
#  'Sunday': 1,
#  'Will': 1,
#  'Cave': 1,
#  'Did': 6,
#  'Save': 2,
#  'Follow': 3,
#  'Leader': 1,
#  "I'll": 4,
#  'Where': 1,
#  'Mysterious': 1,
#  'River': 1,
#  'Suppose': 2,
#  'Tons': 1,
#  'Hook': 147,
#  'Jas': 3,
#  'Ay': 22,
#  'Blackbeard': 2,
#  'Barbecue': 7,
#  'Left-hander': 1,
#  'Claws': 1,
#  'Say': 1,
#  'Long': 5,
#  'Tom': 4,
#  'Yes': 1,
#  'Tell': 1,
#  'Presently': 1,
#  'Tootles': 40,
#  'Poor': 5,
#  'Nibs': 36,
#  'Slightly': 32,
#  'Curly': 20,
#  'Stand': 1,
#  'Twins': 2,
#  'Avast': 2,
#  'A-pirating': 1,
#  'Execution': 1,
#  'Cecco': 12,
#  'Gao': 1,
#  'Guadjo-mo': 1,
#  'Bill': 5,
#  'Jukes': 8,
#  'Walrus': 1,
#  'Flint': 3,
#  'Cookson': 3,
#  'Black': 1,
#  "Murphy's": 1,
#  'Gentleman': 1,
#  'Starkey': 27,
#  'Skylights': 3,
#  'Morgan': 1,
#  'Irish': 1,
#  'Smee': 55,
#  'Noodler': 3,
#  'Robt': 1,
#  'Alf': 2,
#  'Mason': 2,
#  'Main': 2,
#  'James': 5,
#  'Sea-Cook': 2,
#  'Charles': 1,
#  'II': 1,
#  'Stuarts': 1,
#  'Strung': 1,
#  'Piccaninny': 3,
#  'Hurons': 1,
#  'Great': 4,
#  'Big': 1,
#  'Little': 1,
#  'Panther': 2,
#  'Tiger': 13,
#  'Lily': 12,
#  'Dianas': 1,
#  'Piccaninnies': 2,
#  'Yo': 3,
#  'Davy': 2,
#  'Jones': 2,
#  'Captain': 7,
#  'Shall': 3,
#  'Johnny': 5,
#  'Corkscrew': 3,
#  'Scatter': 1,
#  'Odds': 1,
#  'Stranger': 1,
#  'Lagoon': 2,
#  'Aha': 1,
#  'Nought': 1,
#  'Tick': 1,
#  'Almost': 1,
#  'See': 5,
#  'Hullo': 11,
#  'Quick': 4,
#  'Silly': 1,
#  'Pretty': 1,
#  'Hide': 1,
#  'Greetings': 1,
#  'Ah': 7,
#  'Back': 1,
#  'Mine': 1,
#  'Strike': 1,
#  'Listen': 4,
#  'Gut': 1,
#  'Chairs': 1,
#  'Please': 2,
#  'Tut': 2,
#  'Gay': 1,
#  'Quickly': 1,
#  'Never': 10,
#  'Queen': 1,
#  'Mab': 1,
#  'Pie-crust': 1,
#  'Sixth': 1,
#  'Margery': 1,
#  'Robin': 1,
#  'Tiddlywinks': 1,
#  'Make-believe': 1,
#  'Was': 2,
#  'Answer': 1,
#  'Write': 1,
#  'Holidays': 1,
#  'Characters': 1,
#  'Describe': 4,
#  "Mother's": 1,
#  'Party': 1,
#  'Dress': 1,
#  'Kennel': 1,
#  'Inmate': 1,
#  'Dictionary': 1,
#  'Gulch': 2,
#  "Peter's": 4,
#  'Redskin': 2,
#  'Twin': 3,
#  "Lily's": 1,
#  'MERMAIDS': 1,
#  'Marooners': 3,
#  'Rock': 5,
#  'Nevertheless': 2,
#  "Marooners'": 1,
#  'Luff': 1,
#  'Ahoy': 1,
#  'Set': 1,
#  'Better': 2,
#  'Boat': 2,
#  "Hook's": 1,
#  'Swear': 1,
#  'Brimstone': 2,
#  'Lads': 3,
#  'Spirit': 1,
#  'Jolly': 2,
#  'Roger': 2,
#  'Vegetable': 1,
#  'Mineral': 1,
#  'Animal': 1,
#  'Man': 1,
#  'Ordinary': 1,
#  'Wonderful': 1,
#  'Ca': 1,
#  'First': 3,
#  'Help': 1,
#  'Do': 4,
#  'Good-bye': 2,
#  'Pale': 1,
#  'I—want—you—': 1,
#  'Shut': 2,
#  'Every': 2,
#  'White': 2,
#  'Me': 2,
#  'How-do': 1,
#  'Night': 2,
#  'Nights': 2,
#  'May': 2,
#  'Sit': 1,
#  'Watch': 1,
#  'Dance': 1,
#  'Saturday': 4,
#  'True': 1,
#  'Fancy': 1,
#  'WENDY': 1,
#  'Rather': 2,
#  'Hurrah': 1,
#  'Hush': 1,
#  'Think': 1,
#  'London': 1,
#  'Station': 1,
#  'Let': 1,
#  'Thursdays': 1,
#  'Thus': 3,
#  'Peter—': 1,
#  'Above': 1,
#  'Fell': 1,
#  'Lean': 1,
#  'Wolf': 1,
#  'Geo': 1,
#  'Scourie': 1,
#  'Chas': 1,
#  'Turley': 2,
#  'Alsatian': 1,
#  'Foggerty': 1,
#  'Had': 2,
#  'Fain': 1,
#  'Twice': 1,
#  'YOU': 1,
#  'BELIEVE': 1,
#  'IN': 1,
#  'FAIRIES': 1,
#  'Dark': 2,
#  "Slightly's": 1,
#  'Unaware': 1,
#  'Nature': 1,
#  'Kidd': 1,
#  'Creek': 1,
#  'Fame': 1,
#  'Flint—what': 1,
#  'Feared': 1,
#  'Pop': 1,
#  'Bad': 2,
#  'Stow': 1,
#  'Jack': 1,
#  'Joe': 1,
#  'King': 2,
#  'Rule': 1,
#  'Britannia': 1,
#  'Dirty': 1,
#  'Silence': 1,
#  'English': 1,
#  'Tie': 1,
#  'Left': 1,
#  'Fate': 1,
#  'HOOK': 1,
#  'OR': 1,
#  'ME': 1,
#  'THIS': 1,
#  'TIME': 1,
#  'Odd': 1,
#  'Ed': 1,
#  'Teynte': 1,
#  "All's": 1,
#  'Plank': 1,
#  'Till': 1,
#  'Wait': 1,
#  'Shake': 1,
#  'Mullins': 4,
#  'Jonah': 1,
#  "It's": 1,
#  'Cleave': 1,
#  'Down': 1,
#  'Proud': 1,
#  'Rio': 2,
#  'Hitherto': 1,
#  "To't": 1,
#  'kick': 1,
#  'Fifteen': 1,
#  'Gold': 1,
#  'Coast': 1,
#  'June': 1,
#  'Thursday': 3,
#  'Quixotic': 1,
#  'Crowds': 1,
#  'Lots': 1,
#  'Social': 1,
#  'Full': 1,
#  'Home': 2,
#  'Sweet': 1,
#  'Mind': 1,
#  'Hoop': 2,
#  'Would': 1,
#  'Soon': 1,
#  'Keep': 1,
#  "Darling's": 1,
#  'Funny': 1,
#  'Class': 4,
#  'III': 1,
#  'IV': 1,
#  'V.': 1,
#  'Jenkins': 1,
#  'Want': 1,
#  'Jane': 27,
#  "Jane's": 1,
#  'Just': 1,
#  'Lucky': 1,
#  'Woman': 2,
#  'Girl': 1,
#  'Margaret': 3}

# %% [markdown]
# 3. Now that you have built the ```ne_freq_dict``` with the proper nouns as keys and their respective frequencies as values, you can sort the dictionary by value in descending order by running the line given below. Please then print out the top 5 most frequent proper nouns together with their frequencies.
#
#     **NB:** Take care of the data type of ```ne_freq_dict_sorted```. It is not a dictionary any more.
#
# <font color="blue">(3 points)</font>

# %%
ne_freq_dict_sorted = sorted(ne_freq_dict.items(), key=lambda x: x[1], reverse=True)

# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

for i in ne_freq_dict_sorted[0:5]:
    print(i)
# Out:
# ('Peter', 394)
# ('Wendy', 347)
# ('Hook', 147)
# ('John', 132)
# ('Michael', 109)

# %% [markdown]
# ## Task 3: Token Frequency and Type-Token Ratio

# %% [markdown]
# Another common task in computational linguistic researches is to investigate the frequency of each token. To this end, stop words and punctuations are usually removed from the text, as they only have grammatical meanings and are not informative with regard to the content.
#
# 1. Please remove stop words and punctuations from the token list that you obtained from the tokenization in Task 1. To this end, please go through each token in the list, and append all tokens that are neither stop words nor punctuations to the new list ```tokenized_cleaned``` given below.
#
#     For removing stop words, please use the stop word list provided by NLTK, which is already given below. For removing punctuations, please consider using regular expressions.
#
# <font color="blue">(10 points)</font>

# %%
from nltk.corpus import stopwords
import re

# %%
stop_words = stopwords.words('english')
tokenized_cleaned = []

# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

for token in tokenized: 
    if token not in stop_words and re.fullmatch("[!\"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]+", token) == None:
        tokenized_cleaned.append(token)
        
tokenized_cleaned
# Out:
# ['All',
#  'children',
#  'except',
#  'one',
#  'grow',
#  'They',
#  'soon',
#  'know',
#  'grow',
#  'way',
#  'Wendy',
#  'knew',
#  'One',
#  'day',
#  'two',
#  'years',
#  'old',
#  'playing',
#  'garden',
#  'plucked',
#  'another',
#  'flower',
#  'ran',
#  'mother',
#  'I',
#  'suppose',
#  'must',
#  'looked',
#  'rather',
#  'delightful',
#  'Mrs',
#  'Darling',
#  'put',
#  'hand',
#  'heart',
#  'cried',
#  'Oh',
#  'ca',
#  "n't",
#  'remain',
#  'like',
#  'ever',
#  'This',
#  'passed',
#  'subject',
#  'henceforth',
#  'Wendy',
#  'knew',
#  'must',
#  'grow',
#  'You',
#  'always',
#  'know',
#  'two',
#  'Two',
#  'beginning',
#  'end',
#  'Of',
#  'course',
#  'lived',
#  '14',
#  'Wendy',
#  'came',
#  'mother',
#  'chief',
#  'one',
#  'She',
#  'lovely',
#  'lady',
#  'romantic',
#  'mind',
#  'sweet',
#  'mocking',
#  'mouth',
#  'Her',
#  'romantic',
#  'mind',
#  'like',
#  'tiny',
#  'boxes',
#  'one',
#  'within',
#  'come',
#  'puzzling',
#  'East',
#  'however',
#  'many',
#  'discover',
#  'always',
#  'one',
#  'sweet',
#  'mocking',
#  'mouth',
#  'one',
#  'kiss',
#  'Wendy',
#  'could',
#  'never',
#  'get',
#  'though',
#  'perfectly',
#  'conspicuous',
#  'right-hand',
#  'corner',
#  'The',
#  'way',
#  'Mr',
#  'Darling',
#  'many',
#  'gentlemen',
#  'boys',
#  'girl',
#  'discovered',
#  'simultaneously',
#  'loved',
#  'ran',
#  'house',
#  'propose',
#  'except',
#  'Mr',
#  'Darling',
#  'took',
#  'cab',
#  'nipped',
#  'first',
#  'got',
#  'He',
#  'got',
#  'except',
#  'innermost',
#  'box',
#  'kiss',
#  'He',
#  'never',
#  'knew',
#  'box',
#  'time',
#  'gave',
#  'trying',
#  'kiss',
#  'Wendy',
#  'thought',
#  'Napoleon',
#  'could',
#  'got',
#  'I',
#  'picture',
#  'trying',
#  'going',
#  'passion',
#  'slamming',
#  'door',
#  'Mr',
#  'Darling',
#  'used',
#  'boast',
#  'Wendy',
#  'mother',
#  'loved',
#  'respected',
#  'He',
#  'one',
#  'deep',
#  'ones',
#  'know',
#  'stocks',
#  'shares',
#  'Of',
#  'course',
#  'one',
#  'really',
#  'knows',
#  'quite',
#  'seemed',
#  'know',
#  'often',
#  'said',
#  'stocks',
#  'shares',
#  'way',
#  'would',
#  'made',
#  'woman',
#  'respect',
#  'Mrs',
#  'Darling',
#  'married',
#  'white',
#  'first',
#  'kept',
#  'books',
#  'perfectly',
#  'almost',
#  'gleefully',
#  'game',
#  'much',
#  'Brussels',
#  'sprout',
#  'missing',
#  'whole',
#  'cauliflowers',
#  'dropped',
#  'instead',
#  'pictures',
#  'babies',
#  'without',
#  'faces',
#  'She',
#  'drew',
#  'totting',
#  'They',
#  'Mrs',
#  'Darling',
#  "'s",
#  'guesses',
#  'Wendy',
#  'came',
#  'first',
#  'John',
#  'Michael',
#  'For',
#  'week',
#  'two',
#  'Wendy',
#  'came',
#  'doubtful',
#  'whether',
#  'would',
#  'able',
#  'keep',
#  'another',
#  'mouth',
#  'feed',
#  'Mr',
#  'Darling',
#  'frightfully',
#  'proud',
#  'honourable',
#  'sat',
#  'edge',
#  'Mrs',
#  'Darling',
#  "'s",
#  'bed',
#  'holding',
#  'hand',
#  'calculating',
#  'expenses',
#  'looked',
#  'imploringly',
#  'She',
#  'wanted',
#  'risk',
#  'come',
#  'might',
#  'way',
#  'way',
#  'pencil',
#  'piece',
#  'paper',
#  'confused',
#  'suggestions',
#  'begin',
#  'beginning',
#  'Now',
#  "n't",
#  'interrupt',
#  'would',
#  'beg',
#  'I',
#  'one',
#  'pound',
#  'seventeen',
#  'two',
#  'six',
#  'office',
#  'I',
#  'cut',
#  'coffee',
#  'office',
#  'say',
#  'ten',
#  'shillings',
#  'making',
#  'two',
#  'nine',
#  'six',
#  'eighteen',
#  'three',
#  'makes',
#  'three',
#  'nine',
#  'seven',
#  'five',
#  'naught',
#  'naught',
#  'cheque-book',
#  'makes',
#  'eight',
#  'nine',
#  'seven—who',
#  'moving',
#  '—eight',
#  'nine',
#  'seven',
#  'dot',
#  'carry',
#  'seven—do',
#  "n't",
#  'speak',
#  'own—and',
#  'pound',
#  'lent',
#  'man',
#  'came',
#  'door—quiet',
#  'child—dot',
#  'carry',
#  'child—there',
#  "'ve",
#  'done',
#  '—did',
#  'I',
#  'say',
#  'nine',
#  'nine',
#  'seven',
#  'yes',
#  'I',
#  'said',
#  'nine',
#  'nine',
#  'seven',
#  'question',
#  'try',
#  'year',
#  'nine',
#  'nine',
#  'seven',
#  'Of',
#  'course',
#  'George',
#  'cried',
#  'But',
#  'prejudiced',
#  'Wendy',
#  "'s",
#  'favour',
#  'really',
#  'grander',
#  'character',
#  'two',
#  'Remember',
#  'mumps',
#  'warned',
#  'almost',
#  'threateningly',
#  'went',
#  'Mumps',
#  'one',
#  'pound',
#  'I',
#  'put',
#  'I',
#  'daresay',
#  'like',
#  'thirty',
#  'shillings—do',
#  "n't",
#  'speak—measles',
#  'one',
#  'five',
#  'German',
#  'measles',
#  'half',
#  'guinea',
#  'makes',
#  'two',
#  'fifteen',
#  'six—do',
#  "n't",
#  'waggle',
#  'finger—whooping-cough',
#  'say',
#  'fifteen',
#  'shillings',
#  '—and',
#  'went',
#  'added',
#  'differently',
#  'time',
#  'last',
#  'Wendy',
#  'got',
#  'mumps',
#  'reduced',
#  'twelve',
#  'six',
#  'two',
#  'kinds',
#  'measles',
#  'treated',
#  'one',
#  'There',
#  'excitement',
#  'John',
#  'Michael',
#  'even',
#  'narrower',
#  'squeak',
#  'kept',
#  'soon',
#  'might',
#  'seen',
#  'three',
#  'going',
#  'row',
#  'Miss',
#  'Fulsom',
#  "'s",
#  'Kindergarten',
#  'school',
#  'accompanied',
#  'nurse',
#  'Mrs',
#  'Darling',
#  'loved',
#  'everything',
#  'Mr',
#  'Darling',
#  'passion',
#  'exactly',
#  'like',
#  'neighbours',
#  'course',
#  'nurse',
#  'As',
#  'poor',
#  'owing',
#  'amount',
#  'milk',
#  'children',
#  'drank',
#  'nurse',
#  'prim',
#  'Newfoundland',
#  'dog',
#  'called',
#  'Nana',
#  'belonged',
#  'one',
#  'particular',
#  'Darlings',
#  'engaged',
#  'She',
#  'always',
#  'thought',
#  'children',
#  'important',
#  'however',
#  'Darlings',
#  'become',
#  'acquainted',
#  'Kensington',
#  'Gardens',
#  'spent',
#  'spare',
#  'time',
#  'peeping',
#  'perambulators',
#  'much',
#  'hated',
#  'careless',
#  'nursemaids',
#  'followed',
#  'homes',
#  'complained',
#  'mistresses',
#  'She',
#  'proved',
#  'quite',
#  'treasure',
#  'nurse',
#  'How',
#  'thorough',
#  'bath-time',
#  'moment',
#  'night',
#  'one',
#  'charges',
#  'made',
#  'slightest',
#  'cry',
#  'Of',
#  'course',
#  'kennel',
#  'nursery',
#  'She',
#  'genius',
#  'knowing',
#  'cough',
#  'thing',
#  'patience',
#  'needs',
#  'stocking',
#  'around',
#  'throat',
#  'She',
#  'believed',
#  'last',
#  'day',
#  'old-fashioned',
#  'remedies',
#  'like',
#  'rhubarb',
#  'leaf',
#  'made',
#  'sounds',
#  'contempt',
#  'new-fangled',
#  'talk',
#  'germs',
#  'It',
#  'lesson',
#  'propriety',
#  'see',
#  'escorting',
#  'children',
#  'school',
#  'walking',
#  'sedately',
#  'side',
#  'well',
#  'behaved',
#  'butting',
#  'back',
#  'line',
#  'strayed',
#  'On',
#  "John's",
#  'footer',
#  'days',
#  'never',
#  'forgot',
#  'sweater',
#  'usually',
#  'carried',
#  'umbrella',
#  'mouth',
#  'case',
#  'rain',
#  'There',
#  'room',
#  'basement',
#  'Miss',
#  'Fulsom',
#  "'s",
#  'school',
#  'nurses',
#  'wait',
#  'They',
#  'sat',
#  'forms',
#  'Nana',
#  'lay',
#  'floor',
#  'difference',
#  'They',
#  'affected',
#  'ignore',
#  'inferior',
#  'social',
#  'status',
#  'despised',
#  'light',
#  'talk',
#  'She',
#  'resented',
#  'visits',
#  'nursery',
#  'Mrs',
#  'Darling',
#  "'s",
#  'friends',
#  'come',
#  'first',
#  'whipped',
#  'Michael',
#  "'s",
#  'pinafore',
#  'put',
#  'one',
#  'blue',
#  'braiding',
#  'smoothed',
#  'Wendy',
#  'made',
#  'dash',
#  'John',
#  "'s",
#  'hair',
#  'No',
#  'nursery',
#  'could',
#  'possibly',
#  'conducted',
#  'correctly',
#  'Mr',
#  'Darling',
#  'knew',
#  'yet',
#  'sometimes',
#  'wondered',
#  'uneasily',
#  'whether',
#  'neighbours',
#  'talked',
#  'He',
#  'position',
#  'city',
#  'consider',
#  'Nana',
#  'also',
#  'troubled',
#  'another',
#  'way',
#  'He',
#  'sometimes',
#  'feeling',
#  'admire',
#  'I',
#  'know',
#  'admires',
#  'tremendously',
#  'George',
#  'Mrs',
#  'Darling',
#  'would',
#  'assure',
#  'would',
#  'sign',
#  'children',
#  'specially',
#  'nice',
#  'father',
#  'Lovely',
#  'dances',
#  'followed',
#  'servant',
#  'Liza',
#  'sometimes',
#  'allowed',
#  'join',
#  'Such',
#  'midget',
#  'looked',
#  'long',
#  'skirt',
#  'maid',
#  "'s",
#  'cap',
#  'though',
#  'sworn',
#  'engaged',
#  'would',
#  'never',
#  'see',
#  'ten',
#  'The',
#  'gaiety',
#  'romps',
#  'And',
#  'gayest',
#  'Mrs',
#  'Darling',
#  'would',
#  'pirouette',
#  'wildly',
#  'could',
#  'see',
#  'kiss',
#  'dashed',
#  'might',
#  'got',
#  'There',
#  'never',
#  'simpler',
#  'happier',
#  'family',
#  'coming',
#  'Peter',
#  'Pan',
#  'Mrs',
#  'Darling',
#  'first',
#  'heard',
#  'Peter',
#  'tidying',
#  'children',
#  "'s",
#  'minds',
#  'It',
#  'nightly',
#  'custom',
#  'every',
#  'good',
#  'mother',
#  'children',
#  'asleep',
#  'rummage',
#  'minds',
#  'put',
#  'things',
#  'straight',
#  'next',
#  'morning',
#  'repacking',
#  'proper',
#  'places',
#  'many',
#  'articles',
#  'wandered',
#  'day',
#  'If',
#  'could',
#  'keep',
#  'awake',
#  'course',
#  'ca',
#  "n't",
#  'would',
#  'see',
#  'mother',
#  'would',
#  'find',
#  'interesting',
#  'watch',
#  'It',
#  'quite',
#  'like',
#  'tidying',
#  'drawers',
#  'You',
#  'would',
#  'see',
#  'knees',
#  'I',
#  'expect',
#  'lingering',
#  'humorously',
#  'contents',
#  'wondering',
#  'earth',
#  'picked',
#  'thing',
#  'making',
#  'discoveries',
#  'sweet',
#  'sweet',
#  'pressing',
#  'cheek',
#  'nice',
#  'kitten',
#  'hurriedly',
#  'stowing',
#  'sight',
#  'When',
#  'wake',
#  'morning',
#  'naughtiness',
#  'evil',
#  'passions',
#  'went',
#  'bed',
#  'folded',
#  'small',
#  'placed',
#  'bottom',
#  'mind',
#  'top',
#  'beautifully',
#  'aired',
#  'spread',
#  'prettier',
#  'thoughts',
#  'ready',
#  'put',
#  'I',
#  "n't",
#  'know',
#  'whether',
#  'ever',
#  'seen',
#  'map',
#  'person',
#  "'s",
#  'mind',
#  'Doctors',
#  'sometimes',
#  'draw',
#  'maps',
#  'parts',
#  'map',
#  'become',
#  'intensely',
#  'interesting',
#  'catch',
#  'trying',
#  'draw',
#  'map',
#  'child',
#  "'s",
#  'mind',
#  'confused',
#  'keeps',
#  'going',
#  'round',
#  'time',
#  'There',
#  'zigzag',
#  'lines',
#  'like',
#  'temperature',
#  'card',
#  'probably',
#  'roads',
#  'island',
#  'Neverland',
#  'always',
#  'less',
#  'island',
#  'astonishing',
#  'splashes',
#  'colour',
#  'coral',
#  'reefs',
#  'rakish-looking',
#  'craft',
#  'offing',
#  'savages',
#  'lonely',
#  'lairs',
#  'gnomes',
#  'mostly',
#  'tailors',
#  'caves',
#  'river',
#  'runs',
#  'princes',
#  'six',
#  'elder',
#  'brothers',
#  'hut',
#  'fast',
#  'going',
#  'decay',
#  'one',
#  'small',
#  'old',
#  'lady',
#  'hooked',
#  'nose',
#  'It',
#  'would',
#  'easy',
#  'map',
#  'also',
#  'first',
#  'day',
#  'school',
#  'religion',
#  'fathers',
#  'round',
#  'pond',
#  'needle-work',
#  'murders',
#  'hangings',
#  'verbs',
#  'take',
#  'dative',
#  'chocolate',
#  'pudding',
#  'day',
#  'getting',
#  'braces',
#  'say',
#  'ninety-nine',
#  'three-pence',
#  'pulling',
#  'tooth',
#  'either',
#  'part',
#  'island',
#  'another',
#  'map',
#  'showing',
#  'rather',
#  'confusing',
#  'especially',
#  'nothing',
#  'stand',
#  'still',
#  'Of',
#  'course',
#  'Neverlands',
#  'vary',
#  'good',
#  'deal',
#  'John',
#  "'s",
#  'instance',
#  'lagoon',
#  'flamingoes',
#  'flying',
#  'John',
#  'shooting',
#  'Michael',
#  'small',
#  'flamingo',
#  'lagoons',
#  'flying',
#  'John',
#  'lived',
#  'boat',
#  'turned',
#  'upside',
#  'sands',
#  'Michael',
#  'wigwam',
#  'Wendy',
#  'house',
#  'leaves',
#  'deftly',
#  'sewn',
#  'together',
#  'John',
#  'friends',
#  'Michael',
#  'friends',
#  'night',
#  'Wendy',
#  'pet',
#  'wolf',
#  'forsaken',
#  'parents',
#  'whole',
#  'Neverlands',
#  'family',
#  'resemblance',
#  'stood',
#  'still',
#  'row',
#  'could',
#  'say',
#  "'s",
#  'nose',
#  'forth',
#  'On',
#  'magic',
#  'shores',
#  'children',
#  'play',
#  'ever',
#  'beaching',
#  'coracles',
#  'We',
#  'still',
#  'hear',
#  'sound',
#  'surf',
#  'though',
#  'shall',
#  'land',
#  'Of',
#  'delectable',
#  'islands',
#  'Neverland',
#  'snuggest',
#  'compact',
#  'large',
#  'sprawly',
#  'know',
#  'tedious',
#  'distances',
#  'one',
#  'adventure',
#  'another',
#  'nicely',
#  'crammed',
#  'When',
#  'play',
#  'day',
#  'chairs',
#  'table-cloth',
#  'least',
#  'alarming',
#  'two',
#  'minutes',
#  'go',
#  'sleep',
#  ...]

# %% [markdown]
# 2. To investigate the frequency of each token, we will again apply the method used in Task 2 for checking the most frequent proper nouns.
#
#     An empty dictionary ```token_freq_dict``` is defined below. Please construct on this dictionary further so that it contains the tokens in ```tokenized_cleaned``` as keys, and their respective frequencies as values.
#
#     As we would like to consider ```Apple``` and ```apple``` as the same token, please first convert all tokens in ```tokenized_cleaned``` to lower case.
#
# <font color="blue">(7 points)</font>

# %%
token_freq_dict = {}

# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

for token in tokenized_cleaned:
    if token.lower() not in token_freq_dict:
        token_freq_dict[token.lower()] = 1
    else:
        token_freq_dict[token.lower()] += 1

token_freq_dict
# Out:
# {'all': 20,
#  'children': 96,
#  'except': 19,
#  'one': 210,
#  'grow': 8,
#  'they': 112,
#  'soon': 32,
#  'know': 92,
#  'way': 86,
#  'wendy': 354,
#  'knew': 69,
#  'day': 22,
#  'two': 44,
#  'years': 6,
#  'old': 25,
#  'playing': 11,
#  'garden': 1,
#  'plucked': 2,
#  'another': 32,
#  'flower': 3,
#  'ran': 17,
#  'mother': 101,
#  'i': 444,
#  'suppose': 11,
#  'must': 60,
#  'looked': 34,
#  'rather': 43,
#  'delightful': 4,
#  'mrs': 72,
#  'darling': 117,
#  'put': 42,
#  'hand': 55,
#  'heart': 16,
#  'cried': 136,
#  'oh': 58,
#  'ca': 28,
#  "n't": 157,
#  'remain': 4,
#  'like': 91,
#  'ever': 50,
#  'this': 30,
#  'passed': 14,
#  'subject': 4,
#  'henceforth': 2,
#  'you': 65,
#  'always': 54,
#  'beginning': 7,
#  'end': 17,
#  'of': 44,
#  'course': 68,
#  'lived': 8,
#  '14': 2,
#  'came': 76,
#  'chief': 5,
#  'she': 126,
#  'lovely': 20,
#  'lady': 33,
#  'romantic': 4,
#  'mind': 20,
#  'sweet': 14,
#  'mocking': 4,
#  'mouth': 29,
#  'her': 11,
#  'tiny': 5,
#  'boxes': 1,
#  'within': 8,
#  'come': 66,
#  'puzzling': 3,
#  'east': 1,
#  'however': 26,
#  'many': 28,
#  'discover': 3,
#  'kiss': 17,
#  'could': 145,
#  'never': 77,
#  'get': 41,
#  'though': 49,
#  'perfectly': 7,
#  'conspicuous': 1,
#  'right-hand': 2,
#  'corner': 5,
#  'the': 155,
#  'mr': 39,
#  'gentlemen': 4,
#  'boys': 100,
#  'girl': 21,
#  'discovered': 6,
#  'simultaneously': 4,
#  'loved': 13,
#  'house': 46,
#  'propose': 1,
#  'took': 24,
#  'cab': 4,
#  'nipped': 2,
#  'first': 86,
#  'got': 33,
#  'he': 181,
#  'innermost': 1,
#  'box': 5,
#  'time': 121,
#  'gave': 36,
#  'trying': 13,
#  'thought': 78,
#  'napoleon': 1,
#  'picture': 1,
#  'going': 33,
#  'passion': 6,
#  'slamming': 1,
#  'door': 22,
#  'used': 14,
#  'boast': 2,
#  'respected': 1,
#  'deep': 3,
#  'ones': 18,
#  'stocks': 3,
#  'shares': 3,
#  'really': 48,
#  'knows': 9,
#  'quite': 63,
#  'seemed': 23,
#  'often': 19,
#  'said': 358,
#  'would': 216,
#  'made': 49,
#  'woman': 16,
#  'respect': 3,
#  'married': 7,
#  'white': 19,
#  'kept': 13,
#  'books': 1,
#  'almost': 35,
#  'gleefully': 4,
#  'game': 9,
#  'much': 38,
#  'brussels': 1,
#  'sprout': 1,
#  'missing': 2,
#  'whole': 15,
#  'cauliflowers': 1,
#  'dropped': 12,
#  'instead': 20,
#  'pictures': 1,
#  'babies': 5,
#  'without': 35,
#  'faces': 10,
#  'drew': 11,
#  'totting': 2,
#  "'s": 260,
#  'guesses': 2,
#  'john': 132,
#  'michael': 109,
#  'for': 27,
#  'week': 10,
#  'doubtful': 3,
#  'whether': 18,
#  'able': 10,
#  'keep': 13,
#  'feed': 2,
#  'frightfully': 10,
#  'proud': 8,
#  'honourable': 1,
#  'sat': 35,
#  'edge': 3,
#  'bed': 55,
#  'holding': 5,
#  'calculating': 1,
#  'expenses': 2,
#  'imploringly': 2,
#  'wanted': 17,
#  'risk': 1,
#  'might': 29,
#  'pencil': 1,
#  'piece': 4,
#  'paper': 5,
#  'confused': 3,
#  'suggestions': 1,
#  'begin': 1,
#  'now': 34,
#  'interrupt': 1,
#  'beg': 2,
#  'pound': 3,
#  'seventeen': 2,
#  'six': 13,
#  'office': 7,
#  'cut': 13,
#  'coffee': 1,
#  'say': 61,
#  'ten': 8,
#  'shillings': 2,
#  'making': 10,
#  'nine': 13,
#  'eighteen': 1,
#  'three': 28,
#  'makes': 6,
#  'seven': 12,
#  'five': 6,
#  'naught': 2,
#  'cheque-book': 3,
#  'eight': 3,
#  'seven—who': 1,
#  'moving': 5,
#  '—eight': 1,
#  'dot': 1,
#  'carry': 10,
#  'seven—do': 1,
#  'speak': 13,
#  'own—and': 1,
#  'lent': 1,
#  'man': 57,
#  'door—quiet': 1,
#  'child—dot': 1,
#  'child—there': 1,
#  "'ve": 8,
#  'done': 12,
#  '—did': 1,
#  'yes': 54,
#  'question': 10,
#  'try': 5,
#  'year': 8,
#  'george': 20,
#  'but': 88,
#  'prejudiced': 2,
#  'favour': 2,
#  'grander': 1,
#  'character': 2,
#  'remember': 23,
#  'mumps': 3,
#  'warned': 3,
#  'threateningly': 6,
#  'went': 54,
#  'daresay': 2,
#  'thirty': 2,
#  'shillings—do': 1,
#  'speak—measles': 1,
#  'german': 1,
#  'measles': 2,
#  'half': 8,
#  'guinea': 1,
#  'fifteen': 3,
#  'six—do': 1,
#  'waggle': 1,
#  'finger—whooping-cough': 1,
#  '—and': 1,
#  'added': 6,
#  'differently': 1,
#  'last': 59,
#  'reduced': 1,
#  'twelve': 1,
#  'kinds': 1,
#  'treated': 6,
#  'there': 59,
#  'excitement': 1,
#  'even': 52,
#  'narrower': 1,
#  'squeak': 1,
#  'seen': 25,
#  'row': 5,
#  'miss': 2,
#  'fulsom': 2,
#  'kindergarten': 1,
#  'school': 13,
#  'accompanied': 4,
#  'nurse': 12,
#  'everything': 13,
#  'exactly': 13,
#  'neighbours': 3,
#  'as': 27,
#  'poor': 9,
#  'owing': 4,
#  'amount': 1,
#  'milk': 5,
#  'drank': 1,
#  'prim': 1,
#  'newfoundland': 1,
#  'dog': 10,
#  'called': 34,
#  'nana': 64,
#  'belonged': 1,
#  'particular': 2,
#  'darlings': 2,
#  'engaged': 2,
#  'important': 7,
#  'become': 11,
#  'acquainted': 1,
#  'kensington': 3,
#  'gardens': 3,
#  'spent': 4,
#  'spare': 1,
#  'peeping': 7,
#  'perambulators': 2,
#  'hated': 7,
#  'careless': 5,
#  'nursemaids': 1,
#  'followed': 16,
#  'homes': 1,
#  'complained': 1,
#  'mistresses': 1,
#  'proved': 3,
#  'treasure': 3,
#  'how': 23,
#  'thorough': 1,
#  'bath-time': 2,
#  'moment': 59,
#  'night': 61,
#  'charges': 2,
#  'slightest': 3,
#  'cry': 27,
#  'kennel': 19,
#  'nursery': 33,
#  'genius': 3,
#  'knowing': 8,
#  'cough': 1,
#  'thing': 46,
#  'patience': 1,
#  'needs': 1,
#  'stocking': 2,
#  'around': 19,
#  'throat': 1,
#  'believed': 9,
#  'old-fashioned': 1,
#  'remedies': 1,
#  'rhubarb': 1,
#  'leaf': 7,
#  'sounds': 3,
#  'contempt': 3,
#  'new-fangled': 1,
#  'talk': 8,
#  'germs': 1,
#  'it': 171,
#  'lesson': 3,
#  'propriety': 1,
#  'see': 108,
#  'escorting': 1,
#  'walking': 3,
#  'sedately': 1,
#  'side': 17,
#  'well': 43,
#  'behaved': 3,
#  'butting': 1,
#  'back': 62,
#  'line': 4,
#  'strayed': 1,
#  'on': 12,
#  "john's": 1,
#  'footer': 1,
#  'days': 18,
#  'forgot': 10,
#  'sweater': 1,
#  'usually': 5,
#  'carried': 11,
#  'umbrella': 2,
#  'case': 1,
#  'rain': 2,
#  'room': 32,
#  'basement': 1,
#  'nurses': 1,
#  'wait': 6,
#  'forms': 1,
#  'lay': 18,
#  'floor': 23,
#  'difference': 6,
#  'affected': 2,
#  'ignore': 1,
#  'inferior': 3,
#  'social': 2,
#  'status': 1,
#  'despised': 3,
#  'light': 38,
#  'resented': 2,
#  'visits': 1,
#  'friends': 5,
#  'whipped': 4,
#  'pinafore': 1,
#  'blue': 4,
#  'braiding': 1,
#  'smoothed': 1,
#  'dash': 2,
#  'hair': 9,
#  'no': 55,
#  'possibly': 2,
#  'conducted': 2,
#  'correctly': 1,
#  'yet': 20,
#  'sometimes': 30,
#  'wondered': 2,
#  'uneasily': 3,
#  'talked': 4,
#  'position': 3,
#  'city': 1,
#  'consider': 3,
#  'also': 33,
#  'troubled': 5,
#  'feeling': 17,
#  'admire': 2,
#  'admires': 1,
#  'tremendously': 2,
#  'assure': 1,
#  'sign': 3,
#  'specially': 4,
#  'nice': 12,
#  'father': 46,
#  'dances': 2,
#  'servant': 1,
#  'liza': 10,
#  'allowed': 5,
#  'join': 5,
#  'such': 5,
#  'midget': 1,
#  'long': 56,
#  'skirt': 1,
#  'maid': 1,
#  'cap': 1,
#  'sworn': 2,
#  'gaiety': 2,
#  'romps': 1,
#  'and': 56,
#  'gayest': 1,
#  'pirouette': 1,
#  'wildly': 4,
#  'dashed': 2,
#  'simpler': 1,
#  'happier': 1,
#  'family': 4,
#  'coming': 15,
#  'peter': 394,
#  'pan': 25,
#  'heard': 47,
#  'tidying': 2,
#  'minds': 6,
#  'nightly': 1,
#  'custom': 3,
#  'every': 45,
#  'good': 32,
#  'asleep': 24,
#  'rummage': 1,
#  'things': 34,
#  'straight': 7,
#  'next': 15,
#  'morning': 10,
#  'repacking': 1,
#  'proper': 4,
#  'places': 2,
#  'articles': 1,
#  'wandered': 2,
#  'if': 37,
#  'awake': 5,
#  'find': 16,
#  'interesting': 4,
#  'watch': 10,
#  'drawers': 6,
#  'knees': 10,
#  'expect': 4,
#  'lingering': 2,
#  'humorously': 1,
#  'contents': 2,
#  'wondering': 3,
#  'earth': 4,
#  'picked': 2,
#  'discoveries': 1,
#  'pressing': 3,
#  'cheek': 3,
#  'kitten': 1,
#  'hurriedly': 1,
#  'stowing': 1,
#  'sight': 16,
#  'when': 20,
#  'wake': 8,
#  'naughtiness': 1,
#  'evil': 6,
#  'passions': 1,
#  'folded': 2,
#  'small': 10,
#  'placed': 2,
#  'bottom': 2,
#  'top': 7,
#  'beautifully': 5,
#  'aired': 4,
#  'spread': 2,
#  'prettier': 1,
#  'thoughts': 4,
#  'ready': 15,
#  'map': 5,
#  'person': 11,
#  'doctors': 1,
#  'draw': 9,
#  'maps': 2,
#  'parts': 2,
#  'intensely': 1,
#  'catch': 5,
#  'child': 10,
#  'keeps': 2,
#  'round': 51,
#  'zigzag': 1,
#  'lines': 2,
#  'temperature': 1,
#  'card': 1,
#  'probably': 9,
#  'roads': 1,
#  'island': 33,
#  'neverland': 22,
#  'less': 9,
#  'astonishing': 2,
#  'splashes': 1,
#  'colour': 8,
#  'coral': 2,
#  'reefs': 1,
#  'rakish-looking': 2,
#  'craft': 4,
#  'offing': 1,
#  'savages': 2,
#  'lonely': 5,
#  'lairs': 1,
#  'gnomes': 1,
#  'mostly': 3,
#  'tailors': 2,
#  'caves': 2,
#  'river': 3,
#  'runs': 2,
#  'princes': 1,
#  'elder': 1,
#  'brothers': 4,
#  'hut': 1,
#  'fast': 4,
#  'decay': 1,
#  'hooked': 1,
#  'nose': 8,
#  'easy': 6,
#  'religion': 1,
#  'fathers': 1,
#  'pond': 1,
#  'needle-work': 1,
#  'murders': 1,
#  'hangings': 1,
#  'verbs': 1,
#  'take': 35,
#  'dative': 1,
#  'chocolate': 2,
#  'pudding': 1,
#  'getting': 11,
#  'braces': 1,
#  'ninety-nine': 1,
#  'three-pence': 1,
#  'pulling': 5,
#  'tooth': 1,
#  'either': 3,
#  'part': 18,
#  'showing': 10,
#  'confusing': 1,
#  'especially': 6,
#  'nothing': 24,
#  'stand': 7,
#  'still': 62,
#  'neverlands': 2,
#  'vary': 2,
#  'deal': 5,
#  'instance': 5,
#  'lagoon': 31,
#  'flamingoes': 1,
#  'flying': 15,
#  'shooting': 2,
#  'flamingo': 2,
#  'lagoons': 1,
#  'boat': 11,
#  'turned': 12,
#  'upside': 1,
#  'sands': 1,
#  'wigwam': 2,
#  'leaves': 11,
#  'deftly': 2,
#  'sewn': 3,
#  'together': 10,
#  'pet': 4,
#  'wolf': 4,
#  'forsaken': 1,
#  'parents': 8,
#  'resemblance': 2,
#  'stood': 22,
#  'forth': 7,
#  'magic': 2,
#  'shores': 2,
#  'play': 11,
#  'beaching': 1,
#  'coracles': 1,
#  'we': 33,
#  'hear': 33,
#  'sound': 37,
#  'surf': 2,
#  'shall': 27,
#  'land': 7,
#  'delectable': 1,
#  'islands': 1,
#  'snuggest': 1,
#  'compact': 1,
#  'large': 14,
#  'sprawly': 1,
#  'tedious': 2,
#  'distances': 1,
#  'adventure': 14,
#  'nicely': 3,
#  'crammed': 1,
#  'chairs': 3,
#  'table-cloth': 1,
#  'least': 14,
#  'alarming': 2,
#  'minutes': 7,
#  'go': 79,
#  'sleep': 20,
#  'becomes': 1,
#  'real': 17,
#  'that': 36,
#  'night-lights': 9,
#  'occasionally': 2,
#  'travels': 1,
#  'found': 35,
#  'understand': 8,
#  'perplexing': 1,
#  'word': 10,
#  'began': 19,
#  'scrawled': 1,
#  'name': 18,
#  'bolder': 1,
#  'letters': 6,
#  'words': 22,
#  'gazed': 5,
#  'felt': 23,
#  'oddly': 2,
#  'cocky': 2,
#  'appearance': 6,
#  'admitted': 5,
#  'regret': 1,
#  'questioning': 1,
#  'at': 20,
#  'thinking': 16,
#  'childhood': 1,
#  'remembered': 7,
#  'live': 9,
#  'fairies': 23,
#  'odd': 6,
#  'stories': 12,
#  'died': 4,
#  'frightened': 7,
#  'full': 10,
#  'sense': 6,
#  'doubted': 1,
#  'besides': 5,
#  'grown': 10,
#  'assured': 3,
#  'confidently': 1,
#  'size': 4,
#  'meant': 12,
#  'body': 9,
#  'consulted': 1,
#  'smiled': 4,
#  'pooh-pooh': 1,
#  'mark': 4,
#  'nonsense': 3,
#  'putting': 4,
#  'heads': 4,
#  'sort': 7,
#  'idea': 11,
#  'leave': 14,
#  'alone': 15,
#  'blow': 4,
#  'troublesome': 1,
#  'boy': 47,
#  'shock': 1,
#  'strangest': 3,
#  'adventures': 13,
#  'may': 35,
#  'mention': 2,
#  'event': 1,
#  'happened': 13,
#  'wood': 7,
#  'met': 9,
#  'dead': 17,
#  'casual': 1,
#  'disquieting': 2,
#  'revelation': 1,
#  'some': 9,
#  'tree': 32,
#  'certainly': 10,
#  'tolerant': 1,
#  'smile': 8,
#  'believe': 15,
#  'whatever': 4,
#  'mean': 13,
#  'naughty': 3,
#  'wipe': 2,
#  'feet': 15,
#  'sighing': 1,
#  'tidy': 1,
#  'explained': 14,
#  'matter-of-fact': 1,
#  'foot': 12,
#  'played': 6,
#  'pipes': 3,
#  'unfortunately': 5,
#  'woke': 11,
#  'what': 62,
#  'precious': 2,
#  'knocking': 3,
#  'think': 60,
#  'comes': 14,
#  'window': 40,
#  'my': 10,
#  'love': 15,
#  'floors': 1,
#  'were': 1,
#  'true': 22,
#  'near': 13,
#  'natural': 1,
#  'dismiss': 1,
#  'saying': 16,
#  'dreaming': 7,
#  'tell': 44,
#  'lightly': 2,
#  'hurry': 3,
#  'breakfast': 1,
#  'surely': 5,
#  'examined': 4,
#  'carefully': 5,
#  'skeleton': 3,
#  'sure': 35,
#  'grew': 7,
#  'england': 3,
#  'crawled': 4,
#  'peering': 1,
#  'candle': 2,
#  'marks': 1,
#  'strange': 20,
#  'rattled': 3,
#  'poker': 1,
#  'chimney': 10,
#  'tapped': 2,
#  'walls': 4,
#  'let': 66,
#  'tape': 1,
#  'pavement': 1,
#  'sheer': 1,
#  'drop': 4,
#  'spout': 2,
#  'climb': 3,
#  'showed': 13,
#  'extraordinary': 4,
#  'begun': 5,
#  'evening': 17,
#  'bathed': 3,
#  'sung': 1,
#  'till': 23,
#  'slid': 2,
#  'away': 57,
#  'looking': 36,
#  'safe': 7,
#  'cosy': 4,
#  'fears': 1,
#  'tranquilly': 2,
#  'fire': 14,
#  'sew': 2,
#  'something': 28,
#  'birthday': 1,
#  'shirts': 1,
#  'warm': 3,
#  'dimly': 2,
#  'lit': 8,
#  'presently': 8,
#  'sewing': 4,
#  'lap': 3,
#  'then': 65,
#  'head': 22,
#  'nodded': 2,
#  'gracefully': 1,
#  'look': 50,
#  'four': 7,
#  'fourth': 4,
#  'night-light': 1,
#  'while': 7,
#  'slept': 10,
#  'dream': 5,
#  'dreamt': 3,
#  'broken': 6,
#  'alarm': 1,
#  'women': 2,
#  'perhaps': 32,
#  'mothers': 17,
#  'rent': 3,
#  'film': 2,
#  'obscures': 1,
#  'saw': 44,
#  'gap': 1,
#  'trifle': 1,
#  'blew': 8,
#  'open': 20,
#  'bigger': 2,
#  'fist': 2,
#  'darted': 6,
#  'living': 4,
#  'wakened': 4,
#  'started': 3,
#  'somehow': 2,
#  'clad': 1,
#  'juices': 1,
#  'ooze': 1,
#  'trees': 24,
#  'entrancing': 2,
#  'teeth': 8,
#  'grown-up': 4,
#  'gnashed': 2,
#  'little': 102,
#  'pearls': 3,
#  'screamed': 7,
#  'answer': 22,
#  'bell': 31,
#  'opened': 5,
#  'entered': 3,
#  'returned': 15,
#  'growled': 3,
#  'sprang': 6,
#  'leapt': 8,
#  'again': 6,
#  'distress': 3,
#  'killed': 8,
#  'street': 7,
#  'black': 13,
#  'star': 5,
#  'shadow': 19,
#  'closed': 6,
#  'quickly': 18,
#  'late': 8,
#  'slam': 1,
#  'snapped': 5,
#  'ordinary': 7,
#  'kind': 16,
#  'doubt': 6,
#  'best': 28,
#  'hung': 10,
#  'meaning': 5,
#  'us': 51,
#  'easily': 8,
#  'disturbing': 2,
#  'hanging': 7,
#  'washing': 2,
#  'lowered': 2,
#  'tone': 3,
#  'winter': 1,
#  'great-coats': 1,
#  'wet': 2,
#  'towel': 1,
#  'brain': 4,
#  'clear': 4,
#  'shame': 3,
#  'trouble': 1,
#  'decided': 6,
#  'roll': 3,
#  'drawer': 5,
#  'fitting': 2,
#  'opportunity': 5,
#  'telling': 7,
#  'husband': 3,
#  'ah': 8,
#  'later': 1,
#  'never-to-be-forgotten': 1,
#  'friday': 4,
#  'ought': 10,
#  'careful': 2,
#  'afterwards': 6,
#  'responsible': 1,
#  'mea': 2,
#  'culpa': 2,
#  'classical': 1,
#  'education': 1,
#  'thus': 28,
#  'recalling': 3,
#  'fatal': 4,
#  'detail': 2,
#  'stamped': 1,
#  'brains': 1,
#  'bad': 11,
#  'coinage': 1,
#  'accepted': 3,
#  'invitation': 3,
#  'dine': 1,
#  '27': 5,
#  'poured': 3,
#  'medicine': 20,
#  'bowl': 5,
#  'pretended': 6,
#  'eyes': 39,
#  'liking': 2,
#  'parties': 2,
#  'gift': 1,
#  'humour': 5,
#  'dearest': 4,
#  'touchiness': 1,
#  'trifles': 1,
#  'dear': 30,
#  'master': 6,
#  'mistress': 2,
#  'break': 5,
#  'altogether': 1,
#  'handkerchief': 2,
#  'fiend': 2,
#  'bark': 5,
#  'echo': 2,
#  'upbraided': 1,
#  'call': 8,
#  'names': 6,
#  'sit': 6,
#  'empty': 5,
#  'fondly': 1,
#  'smallest': 4,
#  'dreadful': 10,
#  'uneventfully': 1,
#  'precisely': 1,
#  'hundred': 3,
#  'evenings': 3,
#  'water': 33,
#  'bath': 2,
#  'carrying': 6,
#  'wo': 17,
#  'shouted': 9,
#  "o'clock": 2,
#  'sha': 3,
#  'wearing': 8,
#  'evening-gown': 2,
#  'dressed': 2,
#  'early': 3,
#  'necklace': 1,
#  'given': 6,
#  "wendy's": 3,
#  'bracelet': 2,
#  'arm': 15,
#  'asked': 46,
#  'loan': 1,
#  'lend': 1,
#  'older': 2,
#  'occasion': 6,
#  'birth': 2,
#  'happy': 10,
#  'inform': 1,
#  'danced': 6,
#  'joy': 8,
#  'born': 5,
#  'extra': 1,
#  'pomp': 1,
#  'conceived': 2,
#  'due': 2,
#  'male': 2,
#  'ask': 8,
#  'brutally': 1,
#  'want': 28,
#  'nearly': 8,
#  'nobody': 5,
#  'wants': 7,
#  'evening-dress': 1,
#  'third': 7,
#  'hopefully': 1,
#  'arms': 19,
#  'mr.': 7,
#  'recall': 1,
#  'recollections': 1,
#  'rushed': 11,
#  'tornado': 2,
#  'scorning': 1,
#  'indeed': 22,
#  'excuse': 1,
#  'dressing': 2,
#  'party': 5,
#  'gone': 18,
#  'tie': 11,
#  'astounding': 1,
#  'mastery': 1,
#  'yielded': 1,
#  'contest': 1,
#  'occasions': 2,
#  'better': 17,
#  'swallowed': 3,
#  'pride': 5,
#  'made-up': 1,
#  'rushing': 2,
#  'crumpled': 1,
#  'brute': 3,
#  'why': 13,
#  'matter': 11,
#  'yelled': 2,
#  'became': 11,
#  'dangerously': 1,
#  'sarcastic': 1,
#  'not': 17,
#  'neck': 5,
#  'bed-post': 3,
#  'twenty': 3,
#  'times': 11,
#  'begs': 1,
#  'excused': 2,
#  'sufficiently': 3,
#  'impressed': 5,
#  'sternly': 7,
#  'warn': 2,
#  'unless': 5,
#  'dinner': 3,
#  ...}

# %% [markdown]
# 3. Please use the method you learned in Task 2 to sort ```token_freq_dict``` by values in descending order, and print out the top 5 most frequent tokens together with their frequencies.
#
# <font color="blue">(3 points)</font>

# %%
# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

token_freq_dict_sorted = sorted(token_freq_dict.items(), key=lambda x: x[1], reverse=True)

for i in token_freq_dict_sorted[:5]:
    print(i)
# Out:
# ('i', 444)
# ('peter', 394)
# ('said', 358)
# ('wendy', 354)
# ("'s", 260)

# %%
token_freq_dict_sorted
# Out:
# [('i', 444),
#  ('peter', 394),
#  ('said', 358),
#  ('wendy', 354),
#  ("'s", 260),
#  ('would', 216),
#  ('one', 210),
#  ('he', 181),
#  ('hook', 172),
#  ('it', 171),
#  ("n't", 157),
#  ('the', 155),
#  ('could', 145),
#  ('cried', 136),
#  ('john', 132),
#  ('she', 126),
#  ('time', 121),
#  ('darling', 117),
#  ('they', 112),
#  ('michael', 109),
#  ('see', 108),
#  ('little', 102),
#  ('mother', 101),
#  ('boys', 100),
#  ('children', 96),
#  ('know', 92),
#  ('like', 91),
#  ('but', 88),
#  ('way', 86),
#  ('first', 86),
#  ('go', 79),
#  ('thought', 78),
#  ('never', 77),
#  ('came', 76),
#  ('mrs', 72),
#  ('knew', 69),
#  ('course', 68),
#  ('come', 66),
#  ('let', 66),
#  ('you', 65),
#  ('then', 65),
#  ('nana', 64),
#  ('quite', 63),
#  ('back', 62),
#  ('still', 62),
#  ('what', 62),
#  ('say', 61),
#  ('night', 61),
#  ('must', 60),
#  ('think', 60),
#  ('last', 59),
#  ('there', 59),
#  ('moment', 59),
#  ('oh', 58),
#  ('man', 57),
#  ('away', 57),
#  ('long', 56),
#  ('and', 56),
#  ('hand', 55),
#  ('bed', 55),
#  ('no', 55),
#  ('slightly', 55),
#  ('tink', 55),
#  ('pirates', 55),
#  ('smee', 55),
#  ('always', 54),
#  ('yes', 54),
#  ('went', 54),
#  ('even', 52),
#  ('round', 51),
#  ('us', 51),
#  ('ever', 50),
#  ('look', 50),
#  ('though', 49),
#  ('made', 49),
#  ('really', 48),
#  ('heard', 47),
#  ('boy', 47),
#  ('house', 46),
#  ('thing', 46),
#  ('father', 46),
#  ('asked', 46),
#  ('every', 45),
#  ('tootles', 45),
#  ('two', 44),
#  ('of', 44),
#  ('tell', 44),
#  ('saw', 44),
#  ('rather', 43),
#  ('well', 43),
#  ('put', 42),
#  ('get', 41),
#  ('window', 40),
#  ('mr', 39),
#  ('eyes', 39),
#  ('much', 38),
#  ('light', 38),
#  ('home', 38),
#  ('nibs', 38),
#  ('if', 37),
#  ('sound', 37),
#  ('in', 37),
#  ('told', 37),
#  ('gave', 36),
#  ('that', 36),
#  ('looking', 36),
#  ('almost', 35),
#  ('without', 35),
#  ('sat', 35),
#  ('take', 35),
#  ('found', 35),
#  ('may', 35),
#  ('sure', 35),
#  ('voice', 35),
#  ('looked', 34),
#  ('now', 34),
#  ('called', 34),
#  ('things', 34),
#  ('fly', 34),
#  ('lady', 33),
#  ('got', 33),
#  ('going', 33),
#  ('nursery', 33),
#  ('also', 33),
#  ('island', 33),
#  ('we', 33),
#  ('hear', 33),
#  ('water', 33),
#  ('upon', 33),
#  ('pirate', 33),
#  ('soon', 32),
#  ('another', 32),
#  ('room', 32),
#  ('good', 32),
#  ('tree', 32),
#  ('perhaps', 32),
#  ('do', 32),
#  ('face', 32),
#  ('fell', 32),
#  ('ay', 32),
#  ('lagoon', 31),
#  ('bell', 31),
#  ('right', 31),
#  ('this', 30),
#  ('sometimes', 30),
#  ('dear', 30),
#  ('replied', 30),
#  ('captain', 30),
#  ('mouth', 29),
#  ('might', 29),
#  ('tinker', 29),
#  ('ground', 29),
#  ('ca', 28),
#  ('many', 28),
#  ('three', 28),
#  ('something', 28),
#  ('best', 28),
#  ('thus', 28),
#  ('want', 28),
#  ('starkey', 28),
#  ('ship', 28),
#  ('for', 27),
#  ('as', 27),
#  ('cry', 27),
#  ('shall', 27),
#  ('great', 27),
#  ('to', 27),
#  ('rock', 27),
#  ('jane', 27),
#  ('however', 26),
#  ('so', 26),
#  ('others', 26),
#  ('redskins', 26),
#  ('old', 25),
#  ('seen', 25),
#  ('pan', 25),
#  ('a', 25),
#  ('tried', 25),
#  ('air', 25),
#  ('crocodile', 25),
#  ('took', 24),
#  ('asleep', 24),
#  ('nothing', 24),
#  ('trees', 24),
#  ('story', 24),
#  ('make', 24),
#  ('give', 24),
#  ('help', 24),
#  ('flew', 24),
#  ('seemed', 23),
#  ('remember', 23),
#  ('how', 23),
#  ('floor', 23),
#  ('felt', 23),
#  ('fairies', 23),
#  ('till', 23),
#  ('suddenly', 23),
#  ('lost', 23),
#  ('day', 22),
#  ('door', 22),
#  ('neverland', 22),
#  ('stood', 22),
#  ('words', 22),
#  ('true', 22),
#  ('head', 22),
#  ('answer', 22),
#  ('indeed', 22),
#  ('answered', 22),
#  ('save', 22),
#  ('curly', 22),
#  ('bird', 22),
#  ('girl', 21),
#  ('hands', 21),
#  ('longer', 21),
#  ('whispered', 21),
#  ('hat', 21),
#  ('all', 20),
#  ('lovely', 20),
#  ('mind', 20),
#  ('instead', 20),
#  ('george', 20),
#  ('yet', 20),
#  ('when', 20),
#  ('sleep', 20),
#  ('at', 20),
#  ('strange', 20),
#  ('open', 20),
#  ('medicine', 20),
#  ('life', 20),
#  ('glad', 20),
#  ('fairy', 20),
#  ('except', 19),
#  ('often', 19),
#  ('white', 19),
#  ('kennel', 19),
#  ('around', 19),
#  ('began', 19),
#  ('shadow', 19),
#  ('arms', 19),
#  ('o', 19),
#  ('already', 19),
#  ('ones', 18),
#  ('whether', 18),
#  ('days', 18),
#  ('lay', 18),
#  ('part', 18),
#  ('name', 18),
#  ('quickly', 18),
#  ('gone', 18),
#  ('far', 18),
#  ("'m", 18),
#  ('cabin', 18),
#  ('ran', 17),
#  ('end', 17),
#  ('kiss', 17),
#  ('wanted', 17),
#  ('side', 17),
#  ('feeling', 17),
#  ('real', 17),
#  ('dead', 17),
#  ('evening', 17),
#  ('mothers', 17),
#  ('wo', 17),
#  ('better', 17),
#  ('not', 17),
#  ('says', 17),
#  ("'ll", 17),
#  ('his', 17),
#  ('crying', 17),
#  ('mermaids', 17),
#  ('form', 17),
#  ('heart', 16),
#  ('woman', 16),
#  ('followed', 16),
#  ('find', 16),
#  ('sight', 16),
#  ('thinking', 16),
#  ('saying', 16),
#  ('kind', 16),
#  ('flung', 16),
#  ('‘', 16),
#  ('left', 16),
#  ('terrible', 16),
#  ('sea', 16),
#  ('whole', 15),
#  ('coming', 15),
#  ('next', 15),
#  ('ready', 15),
#  ('flying', 15),
#  ('alone', 15),
#  ('believe', 15),
#  ('feet', 15),
#  ('love', 15),
#  ('returned', 15),
#  ('arm', 15),
#  ('new', 15),
#  ('behind', 15),
#  ('dogs', 15),
#  ('silence', 15),
#  ('hour', 15),
#  ('fear', 15),
#  ('liked', 15),
#  ('need', 15),
#  ('passed', 14),
#  ('sweet', 14),
#  ('used', 14),
#  ('large', 14),
#  ('adventure', 14),
#  ('least', 14),
#  ('leave', 14),
#  ('explained', 14),
#  ('comes', 14),
#  ('fire', 14),
#  ('are', 14),
#  ('big', 14),
#  ('among', 14),
#  ('silly', 14),
#  ('dark', 14),
#  ('iron', 14),
#  ('pretty', 14),
#  ('twins', 14),
#  ('nest', 14),
#  ('loved', 13),
#  ('trying', 13),
#  ('kept', 13),
#  ('keep', 13),
#  ('six', 13),
#  ('cut', 13),
#  ('nine', 13),
#  ('speak', 13),
#  ('school', 13),
#  ('everything', 13),
#  ('exactly', 13),
#  ('adventures', 13),
#  ('happened', 13),
#  ('mean', 13),
#  ('near', 13),
#  ('showed', 13),
#  ('black', 13),
#  ('why', 13),
#  ('taken', 13),
#  ('listen', 13),
#  ('anything', 13),
#  ('shut', 13),
#  ('brought', 13),
#  ('rose', 13),
#  ('forgotten', 13),
#  ('merely', 13),
#  ('with', 13),
#  ('sitting', 13),
#  ('tiger', 13),
#  ('twin', 13),
#  ('dropped', 12),
#  ('seven', 12),
#  ('done', 12),
#  ('nurse', 12),
#  ('on', 12),
#  ('nice', 12),
#  ('turned', 12),
#  ('stories', 12),
#  ('meant', 12),
#  ('foot', 12),
#  ('to-night', 12),
#  ('place', 12),
#  ('wish', 12),
#  ('ago', 12),
#  ('beds', 12),
#  ('awfully', 12),
#  ('close', 12),
#  ('use', 12),
#  ('broke', 12),
#  ('who', 12),
#  ('pass', 12),
#  ('make-believe', 12),
#  ('spoke', 12),
#  ('known', 12),
#  ('cecco', 12),
#  ('lily', 12),
#  ('turn', 12),
#  ('plank', 12),
#  ('playing', 11),
#  ('suppose', 11),
#  ('her', 11),
#  ('drew', 11),
#  ('become', 11),
#  ('carried', 11),
#  ('person', 11),
#  ('getting', 11),
#  ('boat', 11),
#  ('leaves', 11),
#  ('play', 11),
#  ('idea', 11),
#  ('woke', 11),
#  ('bad', 11),
#  ('rushed', 11),
#  ('tie', 11),
#  ('matter', 11),
#  ('became', 11),
#  ('times', 11),
#  ('wonder', 11),
#  ('immediately', 11),
#  ('quick', 11),
#  ('waiting', 11),
#  ('exclaimed', 11),
#  ('fall', 11),
#  ('continued', 11),
#  ('none', 11),
#  ('across', 11),
#  ('fight', 11),
#  ('gay', 11),
#  ('claw', 11),
#  ('hullo', 11),
#  ('spring', 11),
#  ('faces', 10),
#  ('week', 10),
#  ('able', 10),
#  ('frightfully', 10),
#  ('making', 10),
#  ('carry', 10),
#  ('question', 10),
#  ('dog', 10),
#  ('forgot', 10),
#  ('liza', 10),
#  ('morning', 10),
#  ('watch', 10),
#  ('knees', 10),
#  ('small', 10),
#  ('child', 10),
#  ('showing', 10),
#  ('together', 10),
#  ('word', 10),
#  ('full', 10),
#  ('grown', 10),
#  ('certainly', 10),
#  ('my', 10),
#  ('chimney', 10),
#  ('slept', 10),
#  ('hung', 10),
#  ('ought', 10),
#  ('dreadful', 10),
#  ('happy', 10),
#  ('tied', 10),
#  ('feel', 10),
#  ('funny', 10),
#  ('show', 10),
#  ('stars', 10),
#  ('inside', 10),
#  ('rest', 10),
#  ('figure', 10),
#  ('short', 10),
#  ("'re", 10),
#  ('slowly', 10),
#  ('struck', 10),
#  ('surprise', 10),
#  ('forward', 10),
#  ('return', 10),
#  ('where', 10),
#  ('reached', 10),
#  ('birds', 10),
#  ('bit', 10),
#  ('change', 10),
#  ('brave', 10),
#  ('tick', 10),
#  ('by', 10),
#  ('knows', 9),
#  ('game', 9),
#  ('poor', 9),
#  ('believed', 9),
#  ('hair', 9),
#  ('draw', 9),
#  ('probably', 9),
#  ('less', 9),
#  ('night-lights', 9),
#  ('live', 9),
#  ('body', 9),
#  ('met', 9),
#  ('some', 9),
#  ('shouted', 9),
#  ('nature', 9),
#  ('sorry', 9),
#  ('danger', 9),
#  ('watching', 9),
#  ('breathing', 9),
#  ('stick', 9),
#  ('dance', 9),
#  ('quiet', 9),
#  ('listened', 9),
#  ('sleeping', 9),
#  ('follow', 9),
#  ('front', 9),
#  ('eggs', 9),
#  ('redskin', 9),
#  ('jukes', 9),
#  ('feared', 9),
#  ('die', 9),
#  ('arrow', 9),
#  ('crow', 9),
#  ('raised', 9),
#  ('hope', 9),
#  ('cleaning', 9),
#  ('grow', 8),
#  ('lived', 8),
#  ('within', 8),
#  ('proud', 8),
#  ('ten', 8),
#  ("'ve", 8),
#  ('year', 8),
#  ('half', 8),
#  ('knowing', 8),
#  ('talk', 8),
#  ('wake', 8),
#  ('colour', 8),
#  ('nose', 8),
#  ('parents', 8),
#  ('understand', 8),
#  ('smile', 8),
#  ('lit', 8),
#  ('presently', 8),
#  ('blew', 8),
#  ('teeth', 8),
#  ('leapt', 8),
#  ('killed', 8),
#  ('late', 8),
#  ('easily', 8),
#  ('ah', 8),
#  ('call', 8),
#  ('wearing', 8),
#  ('joy', 8),
#  ('ask', 8),
#  ('nearly', 8),
#  ('bring', 8),
#  ('stop', 8),
#  ('world', 8),
#  ('unhappy', 8),
#  ('manner', 8),
#  ('pleased', 8),
#  ('is', 8),
#  ('held', 8),
#  ('toward', 8),
#  ('questions', 8),
#  ('pieces', 8),
#  ('keeping', 8),
#  ('girls', 8),
#  ('understood', 8),
#  ('wind', 8),
#  ('tails', 8),
#  ('sharp', 8),
#  ('since', 8),
#  ('reach', 8),
#  ('sir', 8),
#  ('meet', 8),
#  ('blood', 8),
#  ('dagger', 8),
#  ('song', 8),
#  ('cast', 8),
#  ('hollow', 8),
#  ('eye', 8),
#  ('mainland', 8),
#  ('stopped', 8),
#  ('fit', 8),
#  ('written', 8),
#  ('walk', 8),
#  ('had', 8),
#  ('feelings', 8),
#  ('board', 8),
#  ('heartless', 8),
#  ('beginning', 7),
#  ('perfectly', 7),
#  ('married', 7),
#  ('office', 7),
#  ('important', 7),
#  ('peeping', 7),
#  ('hated', 7),
#  ('leaf', 7),
#  ('straight', 7),
#  ('top', 7),
#  ('stand', 7),
#  ('forth', 7),
#  ('land', 7),
#  ('minutes', 7),
#  ('remembered', 7),
#  ('frightened', 7),
#  ('sort', 7),
#  ('wood', 7),
#  ('dreaming', 7),
#  ('grew', 7),
#  ('safe', 7),
#  ('four', 7),
#  ('while', 7),
#  ('screamed', 7),
#  ('street', 7),
#  ('ordinary', 7),
#  ('hanging', 7),
#  ('telling', 7),
#  ('wants', 7),
#  ('third', 7),
#  ('mr.', 7),
#  ('sternly', 7),
#  ('fate', 7),
#  ('men', 7),
#  ('fair', 7),
#  ('neither', 7),
#  ('calling', 7),
#  ('beautiful', 7),
#  ('anxious', 7),
#  ('mouths', 7),
#  ('second', 7),
#  ('low', 7),
#  ('blown', 7),
#  ('softly', 7),
#  ('awful', 7),
#  ('frightful', 7),
#  ('listening', 7),
#  ('set', 7),
#  ('young', 7),
#  ('run', 7),
#  ('baby', 7),
#  ('laugh', 7),
#  ('spirit', 7),
#  ('oo', 7),
#  ('signed', 7),
#  ('here', 7),
#  ('figures', 7),
#  ('cold', 7),
#  ('gaily', 7),
#  ('pretend', 7),
#  ('strike', 7),
#  ('waited', 7),
#  ('passing', 7),
#  ('after', 7),
#  ('several', 7),
#  ('smoke', 7),
#  ('beasts', 7),
#  ('kill', 7),
#  ("bo'sun", 7),
#  ('barbecue', 7),
#  ('afraid', 7),
#  ('circle', 7),
#  ('darkness', 7),
#  ('hoped', 7),
#  ('present', 7),
#  ('yo', 7),
#  ('ho', 7),
#  ('lips', 7),
#  ('finished', 7),
#  ('instantly', 7),
#  ('step', 7),
#  ('twice', 7),
#  ('meal', 7),
#  ('or', 7),
#  ('describe', 7),
#  ('forget', 7),
#  ('complain', 7),
#  ('deck', 7),
#  ('years', 6),
#  ('discovered', 6),
#  ('passion', 6),
#  ('makes', 6),
#  ('five', 6),
#  ('threateningly', 6),
#  ('added', 6),
#  ('treated', 6),
#  ('wait', 6),
#  ('difference', 6),
#  ('minds', 6),
#  ('drawers', 6),
#  ('evil', 6),
#  ('easy', 6),
#  ('especially', 6),
#  ('letters', 6),
#  ('appearance', 6),
#  ('odd', 6),
#  ('sense', 6),
#  ('played', 6),
#  ('broken', 6),
#  ('darted', 6),
#  ('sprang', 6),
#  ('again', 6),
#  ('closed', 6),
#  ('doubt', 6),
#  ('decided', 6),
#  ('afterwards', 6),
#  ('pretended', 6),
#  ('master', 6),
#  ('names', 6),
#  ('sit', 6),
#  ('carrying', 6),
#  ('given', 6),
#  ('occasion', 6),
#  ('danced', 6),
#  ('rage', 6),
#  ('tears', 6),
#  ('strong', 6),
#  ('glass', 6),
#  ('retorted', 6),
#  ('breath', 6),
#  ('demanded', 6),
#  ('mine', 6),
#  ('fun', 6),
#  ('tail', 6),
#  ('red', 6),
#  ('vain', 6),
#  ('alas', 6),
#  ('dragged', 6),
#  ('admiration', 6),
#  ('language', 6),
#  ('fond', 6),
#  ('growing', 6),
#  ('eagerly', 6),
#  ('thimble', 6),
#  ('people', 6),
#  ('touch', 6),
#  ('nearer', 6),
#  ('clock', 6),
#  ('disappeared', 6),
#  ('which', 6),
#  ('mummy', 6),
#  ('pity', 6),
#  ('success', 6),
#  ('promise', 6),
#  ('once', 6),
#  ('did', 6),
#  ('jolly', 6),
#  ('floating', 6),
#  ('along', 6),
#  ('certain', 6),
#  ('moons', 6),
#  ('shoulder', 6),
#  ('courage', 6),
#  ('shot', 6),
#  ('else', 6),
#  ('melancholy', 6),
#  ('lest', 6),
#  ('dress', 6),
#  ('caught', 6),
#  ('cake', 6),
#  ('wolves', 6),
#  ('legs', 6),
#  ('gathered', 6),
#  ('fitted', 6),
#  ('breast', 6),
#  ('standing', 6),
#  ('dreams', 6),
#  ('firmly', 6),
#  ('lives', 6),
#  ('tut', 6),
#  ('needed', 6),
#  ('remained', 6),
#  ('sword', 6),
#  ('hard', 6),
#  ('stayed', 6),
#  ('innocent', 6),
#  ('mast', 6),
#  ('space', 6),
#  ('weapons', 6),
#  ('class', 6),
#  ('chief', 5),
#  ('tiny', 5),
#  ('corner', 5),
#  ('box', 5),
#  ('babies', 5),
#  ('holding', 5),
#  ('paper', 5),
#  ('moving', 5),
#  ('try', 5),
#  ('row', 5),
#  ('milk', 5),
#  ('careless', 5),
#  ('usually', 5),
#  ('friends', 5),
#  ('troubled', 5),
#  ('allowed', 5),
#  ('join', 5),
#  ('such', 5),
#  ('awake', 5),
#  ('beautifully', 5),
#  ('map', 5),
#  ('catch', 5),
#  ('lonely', 5),
#  ('pulling', 5),
#  ('deal', 5),
#  ('instance', 5),
#  ('gazed', 5),
#  ('admitted', 5),
#  ('besides', 5),
#  ('unfortunately', 5),
#  ('surely', 5),
#  ('carefully', 5),
#  ('begun', 5),
#  ('dream', 5),
#  ('opened', 5),
#  ('star', 5),
#  ('snapped', 5),
#  ('meaning', 5),
#  ('drawer', 5),
#  ('opportunity', 5),
#  ('27', 5),
#  ('bowl', 5),
#  ('humour', 5),
#  ('break', 5),
#  ('bark', 5),
#  ('empty', 5),
#  ('born', 5),
#  ('nobody', 5),
#  ('party', 5),
#  ('pride', 5),
#  ('neck', 5),
#  ('impressed', 5),
#  ('unless', 5),
#  ('brushed', 5),
#  ('hidden', 5),
#  ('puzzled', 5),
#  ('missed', 5),
#  ('servants', 5),
#  ('determined', 5),
#  ('meantime', 5),
#  ('singing', 5),
#  ('dust', 5),
#  ('seem', 5),
#  ('sharply', 5),
#  ('ignorance', 5),
#  ('hurt', 5),
#  ('opinion', 5),
#  ('crowing', 5),
#  ('chain', 5),
#  ('surprised', 5),
#  ('charming', 5),
#  ('drawing-room', 5),
#  ('rising', 5),
#  ('sudden', 5),
#  ('ass', 5),
#  ('sent', 5),
#  ('reply', 5),
#  ('erect', 5),
#  ('offensive', 5),
#  ('build', 5),
#  ('ordered', 5),
#  ('teach', 5),
#  ('mermaid', 5),
#  ('clothes', 5),
#  ('hide', 5),
#  ('taking', 5),
#  ('gentle', 5),
#  ('ceased', 5),
#  ('seeing', 5),
#  ('burst', 5),
#  ('good-bye', 5),
#  ('knee', 5),
#  ('goes', 5),
#  ('finger', 5),
#  ('friend', 5),
#  ('anon', 5),
#  ('shadows', 5),
#  ('ear', 5),
#  ('tea', 5),
#  ('thinks', 5),
#  ('worth', 5),
#  ('rule', 5),
#  ('care', 5),
#  ('bill', 5),
#  ('crew', 5),
#  ('mullins', 5),
#  ('james', 5),
#  ('clung', 5),
#  ('somewhat', 5),
#  ('tribe', 5),
#  ('fallen', 5),
#  ('savage', 5),
#  ('rolled', 5),
#  ('these', 5),
#  ('johnny', 5),
#  ('unknown', 5),
#  ('shore', 5),
#  ('swimming', 5),
#  ('eat', 5),
#  ('have', 5),
#  ('victory', 5),
#  ('direction', 5),
#  ('rang', 5),
#  ('simple', 5),
#  ('saved', 5),
#  ('raising', 5),
#  ('built', 5),
#  ('difficult', 5),
#  ('simply', 5),
#  ('shape', 5),
#  ('possible', 5),
#  ('was', 5),
#  ('choose', 5),
#  ('orders', 5),
#  ('dared', 5),
#  ('hours', 5),
#  ('swim', 5),
#  ('daughter', 5),
#  ('lantern', 5),
#  ('scarcely', 5),
#  ('pain', 5),
#  ('fighting', 5),
#  ('truth', 5),
#  ('kite', 5),
#  ('usual', 5),
#  ('braves', 5),
#  ('barred', 5),
#  ('tom-tom', 5),
#  ('cloak', 5),
#  ('poisoned', 5),
#  ('gesture', 5),
#  ('ticking', 5),
#  ('cypher', 5),
#  ('delightful', 4),
#  ('remain', 4),
#  ('subject', 4),
#  ('romantic', 4),
#  ('mocking', 4),
#  ('gentlemen', 4),
#  ('simultaneously', 4),
#  ('cab', 4),
#  ('gleefully', 4),
#  ('piece', 4),
#  ('accompanied', 4),
#  ('owing', 4),
#  ('spent', 4),
#  ('line', 4),
#  ('whipped', 4),
#  ('blue', 4),
#  ('talked', 4),
#  ('specially', 4),
#  ('wildly', 4),
#  ('family', 4),
#  ('proper', 4),
#  ('interesting', 4),
#  ('expect', 4),
#  ('earth', 4),
#  ('aired', 4),
#  ('thoughts', 4),
#  ('craft', 4),
#  ('brothers', 4),
#  ('fast', 4),
#  ('pet', 4),
#  ('wolf', 4),
#  ('died', 4),
#  ('size', 4),
#  ('smiled', 4),
#  ('mark', 4),
#  ('putting', 4),
#  ('heads', 4),
#  ('blow', 4),
#  ('whatever', 4),
#  ('examined', 4),
#  ('crawled', 4),
#  ('walls', 4),
#  ('drop', 4),
#  ('extraordinary', 4),
#  ('cosy', 4),
#  ('sewing', 4),
#  ('fourth', 4),
#  ('living', 4),
#  ('wakened', 4),
#  ('grown-up', 4),
#  ('brain', 4),
#  ('clear', 4),
#  ('friday', 4),
#  ('fatal', 4),
#  ('dearest', 4),
#  ('smallest', 4),
#  ('fine', 4),
#  ('prevent', 4),
#  ('looks', 4),
#  ('wife', 4),
#  ('bottle', 4),
#  ('age', 4),
#  ('faithful', 4),
#  ('shuddering', 4),
#  ('hold', 4),
#  ('rapped', 4),
#  ('bathroom', 4),
#  ('drink', 4),
#  ('doubtfully', 4),
#  ('tear', 4),
#  ('noble', 4),
#  ('yard', 4),
#  ('instant', 4),
#  ('knuckles', 4),
#  ('happen', 4),
#  ('can', 4),
#  ('distant', 4),
#  ('bells', 4),
#  ('chest', 4),
#  ('delight', 4),
#  ('interested', 4),
#  ('polite', 4),
#  ('bowed', 4),
#  ('address', 4),
#  ('tragedy', 4),
#  ('fortunately', 4),
#  ('properly', 4),
#  ('clever', 4),
#  ('crowed', 4),
#  ('fascinating', 4),
#  ('shocked', 4),
#  ...]

# %% [markdown]
# 4. The vocabulary richness of a text is often measured by **type-token ratio** (TTR). TTR is defined as the total number of *unique* tokens (i.e., *types*) divided by the total number of tokens in a given text.
#
#     E.g., For the text ```John likes apple and Mary likes apple too```, the total number of types (unique tokens) would be 6: ```{'John', 'likes', 'apple', 'and', 'Mary', 'too'}```  (Note that ```likes``` and ```apple``` appeared two times). The total number of tokens would be 8. Thus, the TTR is 6/8 = 0.75.
#
#     Please calculate the TTR of the text ```peterpan_cleaned.txt```.
#
#     **Tips:** You can get the total number of types by inquiring how many keys the ```token_freq_dict``` contains.
#
# <font color="blue">(10 points)</font>

# %%
# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.
    
ttr = len(token_freq_dict) / len(tokenized_cleaned)
ttr
# Out:
# 0.19765500956723528

# %% [markdown]
# ## Task 4: N-grams

# %% [markdown]
# One can not only find out the frequency of single tokens in a text. Researchers are also often interested in the frequencies of the so-called **N-grams**, i.e., sequences of *N* tokens. Here we will work on the so-called *bigrams*, i.e., sequences of 2 tokens.
#
# E.g., All bigrams of the list ```['Winterthur', 'is', 'a', 'city', 'in', 'Switzerland']``` are:
#
# ```['Wintherthur is', 'is a', 'a city', 'city in', 'in Switzerland']```
#
# 1. Please use a **while-loop** or a **for-loop** to get all bigrams of the list ```tokenized_cleaned``` resulted from Task 3, and store them in the list ```bigrams``` given below.
#
#     **NB:** Actually, NLTK also provides off-the-shelf methods for getting N-grams from a list. However, for the purpose of practicing, please DO use a while-loop or a for-loop to complete this task.
#
# <font color="blue">(25 points)</font>

# %%
bigrams = []

# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

i = 0
while i < len(tokenized_cleaned) - 1:
    bigrams.append(" ".join(tokenized_cleaned[i:i+2]))
    i += 1
    
bigrams
# Out:
# ['All children',
#  'children except',
#  'except one',
#  'one grow',
#  'grow They',
#  'They soon',
#  'soon know',
#  'know grow',
#  'grow way',
#  'way Wendy',
#  'Wendy knew',
#  'knew One',
#  'One day',
#  'day two',
#  'two years',
#  'years old',
#  'old playing',
#  'playing garden',
#  'garden plucked',
#  'plucked another',
#  'another flower',
#  'flower ran',
#  'ran mother',
#  'mother I',
#  'I suppose',
#  'suppose must',
#  'must looked',
#  'looked rather',
#  'rather delightful',
#  'delightful Mrs',
#  'Mrs Darling',
#  'Darling put',
#  'put hand',
#  'hand heart',
#  'heart cried',
#  'cried Oh',
#  'Oh ca',
#  "ca n't",
#  "n't remain",
#  'remain like',
#  'like ever',
#  'ever This',
#  'This passed',
#  'passed subject',
#  'subject henceforth',
#  'henceforth Wendy',
#  'Wendy knew',
#  'knew must',
#  'must grow',
#  'grow You',
#  'You always',
#  'always know',
#  'know two',
#  'two Two',
#  'Two beginning',
#  'beginning end',
#  'end Of',
#  'Of course',
#  'course lived',
#  'lived 14',
#  '14 Wendy',
#  'Wendy came',
#  'came mother',
#  'mother chief',
#  'chief one',
#  'one She',
#  'She lovely',
#  'lovely lady',
#  'lady romantic',
#  'romantic mind',
#  'mind sweet',
#  'sweet mocking',
#  'mocking mouth',
#  'mouth Her',
#  'Her romantic',
#  'romantic mind',
#  'mind like',
#  'like tiny',
#  'tiny boxes',
#  'boxes one',
#  'one within',
#  'within come',
#  'come puzzling',
#  'puzzling East',
#  'East however',
#  'however many',
#  'many discover',
#  'discover always',
#  'always one',
#  'one sweet',
#  'sweet mocking',
#  'mocking mouth',
#  'mouth one',
#  'one kiss',
#  'kiss Wendy',
#  'Wendy could',
#  'could never',
#  'never get',
#  'get though',
#  'though perfectly',
#  'perfectly conspicuous',
#  'conspicuous right-hand',
#  'right-hand corner',
#  'corner The',
#  'The way',
#  'way Mr',
#  'Mr Darling',
#  'Darling many',
#  'many gentlemen',
#  'gentlemen boys',
#  'boys girl',
#  'girl discovered',
#  'discovered simultaneously',
#  'simultaneously loved',
#  'loved ran',
#  'ran house',
#  'house propose',
#  'propose except',
#  'except Mr',
#  'Mr Darling',
#  'Darling took',
#  'took cab',
#  'cab nipped',
#  'nipped first',
#  'first got',
#  'got He',
#  'He got',
#  'got except',
#  'except innermost',
#  'innermost box',
#  'box kiss',
#  'kiss He',
#  'He never',
#  'never knew',
#  'knew box',
#  'box time',
#  'time gave',
#  'gave trying',
#  'trying kiss',
#  'kiss Wendy',
#  'Wendy thought',
#  'thought Napoleon',
#  'Napoleon could',
#  'could got',
#  'got I',
#  'I picture',
#  'picture trying',
#  'trying going',
#  'going passion',
#  'passion slamming',
#  'slamming door',
#  'door Mr',
#  'Mr Darling',
#  'Darling used',
#  'used boast',
#  'boast Wendy',
#  'Wendy mother',
#  'mother loved',
#  'loved respected',
#  'respected He',
#  'He one',
#  'one deep',
#  'deep ones',
#  'ones know',
#  'know stocks',
#  'stocks shares',
#  'shares Of',
#  'Of course',
#  'course one',
#  'one really',
#  'really knows',
#  'knows quite',
#  'quite seemed',
#  'seemed know',
#  'know often',
#  'often said',
#  'said stocks',
#  'stocks shares',
#  'shares way',
#  'way would',
#  'would made',
#  'made woman',
#  'woman respect',
#  'respect Mrs',
#  'Mrs Darling',
#  'Darling married',
#  'married white',
#  'white first',
#  'first kept',
#  'kept books',
#  'books perfectly',
#  'perfectly almost',
#  'almost gleefully',
#  'gleefully game',
#  'game much',
#  'much Brussels',
#  'Brussels sprout',
#  'sprout missing',
#  'missing whole',
#  'whole cauliflowers',
#  'cauliflowers dropped',
#  'dropped instead',
#  'instead pictures',
#  'pictures babies',
#  'babies without',
#  'without faces',
#  'faces She',
#  'She drew',
#  'drew totting',
#  'totting They',
#  'They Mrs',
#  'Mrs Darling',
#  "Darling 's",
#  "'s guesses",
#  'guesses Wendy',
#  'Wendy came',
#  'came first',
#  'first John',
#  'John Michael',
#  'Michael For',
#  'For week',
#  'week two',
#  'two Wendy',
#  'Wendy came',
#  'came doubtful',
#  'doubtful whether',
#  'whether would',
#  'would able',
#  'able keep',
#  'keep another',
#  'another mouth',
#  'mouth feed',
#  'feed Mr',
#  'Mr Darling',
#  'Darling frightfully',
#  'frightfully proud',
#  'proud honourable',
#  'honourable sat',
#  'sat edge',
#  'edge Mrs',
#  'Mrs Darling',
#  "Darling 's",
#  "'s bed",
#  'bed holding',
#  'holding hand',
#  'hand calculating',
#  'calculating expenses',
#  'expenses looked',
#  'looked imploringly',
#  'imploringly She',
#  'She wanted',
#  'wanted risk',
#  'risk come',
#  'come might',
#  'might way',
#  'way way',
#  'way pencil',
#  'pencil piece',
#  'piece paper',
#  'paper confused',
#  'confused suggestions',
#  'suggestions begin',
#  'begin beginning',
#  'beginning Now',
#  "Now n't",
#  "n't interrupt",
#  'interrupt would',
#  'would beg',
#  'beg I',
#  'I one',
#  'one pound',
#  'pound seventeen',
#  'seventeen two',
#  'two six',
#  'six office',
#  'office I',
#  'I cut',
#  'cut coffee',
#  'coffee office',
#  'office say',
#  'say ten',
#  'ten shillings',
#  'shillings making',
#  'making two',
#  'two nine',
#  'nine six',
#  'six eighteen',
#  'eighteen three',
#  'three makes',
#  'makes three',
#  'three nine',
#  'nine seven',
#  'seven five',
#  'five naught',
#  'naught naught',
#  'naught cheque-book',
#  'cheque-book makes',
#  'makes eight',
#  'eight nine',
#  'nine seven—who',
#  'seven—who moving',
#  'moving —eight',
#  '—eight nine',
#  'nine seven',
#  'seven dot',
#  'dot carry',
#  'carry seven—do',
#  "seven—do n't",
#  "n't speak",
#  'speak own—and',
#  'own—and pound',
#  'pound lent',
#  'lent man',
#  'man came',
#  'came door—quiet',
#  'door—quiet child—dot',
#  'child—dot carry',
#  'carry child—there',
#  "child—there 've",
#  "'ve done",
#  'done —did',
#  '—did I',
#  'I say',
#  'say nine',
#  'nine nine',
#  'nine seven',
#  'seven yes',
#  'yes I',
#  'I said',
#  'said nine',
#  'nine nine',
#  'nine seven',
#  'seven question',
#  'question try',
#  'try year',
#  'year nine',
#  'nine nine',
#  'nine seven',
#  'seven Of',
#  'Of course',
#  'course George',
#  'George cried',
#  'cried But',
#  'But prejudiced',
#  'prejudiced Wendy',
#  "Wendy 's",
#  "'s favour",
#  'favour really',
#  'really grander',
#  'grander character',
#  'character two',
#  'two Remember',
#  'Remember mumps',
#  'mumps warned',
#  'warned almost',
#  'almost threateningly',
#  'threateningly went',
#  'went Mumps',
#  'Mumps one',
#  'one pound',
#  'pound I',
#  'I put',
#  'put I',
#  'I daresay',
#  'daresay like',
#  'like thirty',
#  'thirty shillings—do',
#  "shillings—do n't",
#  "n't speak—measles",
#  'speak—measles one',
#  'one five',
#  'five German',
#  'German measles',
#  'measles half',
#  'half guinea',
#  'guinea makes',
#  'makes two',
#  'two fifteen',
#  'fifteen six—do',
#  "six—do n't",
#  "n't waggle",
#  'waggle finger—whooping-cough',
#  'finger—whooping-cough say',
#  'say fifteen',
#  'fifteen shillings',
#  'shillings —and',
#  '—and went',
#  'went added',
#  'added differently',
#  'differently time',
#  'time last',
#  'last Wendy',
#  'Wendy got',
#  'got mumps',
#  'mumps reduced',
#  'reduced twelve',
#  'twelve six',
#  'six two',
#  'two kinds',
#  'kinds measles',
#  'measles treated',
#  'treated one',
#  'one There',
#  'There excitement',
#  'excitement John',
#  'John Michael',
#  'Michael even',
#  'even narrower',
#  'narrower squeak',
#  'squeak kept',
#  'kept soon',
#  'soon might',
#  'might seen',
#  'seen three',
#  'three going',
#  'going row',
#  'row Miss',
#  'Miss Fulsom',
#  "Fulsom 's",
#  "'s Kindergarten",
#  'Kindergarten school',
#  'school accompanied',
#  'accompanied nurse',
#  'nurse Mrs',
#  'Mrs Darling',
#  'Darling loved',
#  'loved everything',
#  'everything Mr',
#  'Mr Darling',
#  'Darling passion',
#  'passion exactly',
#  'exactly like',
#  'like neighbours',
#  'neighbours course',
#  'course nurse',
#  'nurse As',
#  'As poor',
#  'poor owing',
#  'owing amount',
#  'amount milk',
#  'milk children',
#  'children drank',
#  'drank nurse',
#  'nurse prim',
#  'prim Newfoundland',
#  'Newfoundland dog',
#  'dog called',
#  'called Nana',
#  'Nana belonged',
#  'belonged one',
#  'one particular',
#  'particular Darlings',
#  'Darlings engaged',
#  'engaged She',
#  'She always',
#  'always thought',
#  'thought children',
#  'children important',
#  'important however',
#  'however Darlings',
#  'Darlings become',
#  'become acquainted',
#  'acquainted Kensington',
#  'Kensington Gardens',
#  'Gardens spent',
#  'spent spare',
#  'spare time',
#  'time peeping',
#  'peeping perambulators',
#  'perambulators much',
#  'much hated',
#  'hated careless',
#  'careless nursemaids',
#  'nursemaids followed',
#  'followed homes',
#  'homes complained',
#  'complained mistresses',
#  'mistresses She',
#  'She proved',
#  'proved quite',
#  'quite treasure',
#  'treasure nurse',
#  'nurse How',
#  'How thorough',
#  'thorough bath-time',
#  'bath-time moment',
#  'moment night',
#  'night one',
#  'one charges',
#  'charges made',
#  'made slightest',
#  'slightest cry',
#  'cry Of',
#  'Of course',
#  'course kennel',
#  'kennel nursery',
#  'nursery She',
#  'She genius',
#  'genius knowing',
#  'knowing cough',
#  'cough thing',
#  'thing patience',
#  'patience needs',
#  'needs stocking',
#  'stocking around',
#  'around throat',
#  'throat She',
#  'She believed',
#  'believed last',
#  'last day',
#  'day old-fashioned',
#  'old-fashioned remedies',
#  'remedies like',
#  'like rhubarb',
#  'rhubarb leaf',
#  'leaf made',
#  'made sounds',
#  'sounds contempt',
#  'contempt new-fangled',
#  'new-fangled talk',
#  'talk germs',
#  'germs It',
#  'It lesson',
#  'lesson propriety',
#  'propriety see',
#  'see escorting',
#  'escorting children',
#  'children school',
#  'school walking',
#  'walking sedately',
#  'sedately side',
#  'side well',
#  'well behaved',
#  'behaved butting',
#  'butting back',
#  'back line',
#  'line strayed',
#  'strayed On',
#  "On John's",
#  "John's footer",
#  'footer days',
#  'days never',
#  'never forgot',
#  'forgot sweater',
#  'sweater usually',
#  'usually carried',
#  'carried umbrella',
#  'umbrella mouth',
#  'mouth case',
#  'case rain',
#  'rain There',
#  'There room',
#  'room basement',
#  'basement Miss',
#  'Miss Fulsom',
#  "Fulsom 's",
#  "'s school",
#  'school nurses',
#  'nurses wait',
#  'wait They',
#  'They sat',
#  'sat forms',
#  'forms Nana',
#  'Nana lay',
#  'lay floor',
#  'floor difference',
#  'difference They',
#  'They affected',
#  'affected ignore',
#  'ignore inferior',
#  'inferior social',
#  'social status',
#  'status despised',
#  'despised light',
#  'light talk',
#  'talk She',
#  'She resented',
#  'resented visits',
#  'visits nursery',
#  'nursery Mrs',
#  'Mrs Darling',
#  "Darling 's",
#  "'s friends",
#  'friends come',
#  'come first',
#  'first whipped',
#  'whipped Michael',
#  "Michael 's",
#  "'s pinafore",
#  'pinafore put',
#  'put one',
#  'one blue',
#  'blue braiding',
#  'braiding smoothed',
#  'smoothed Wendy',
#  'Wendy made',
#  'made dash',
#  'dash John',
#  "John 's",
#  "'s hair",
#  'hair No',
#  'No nursery',
#  'nursery could',
#  'could possibly',
#  'possibly conducted',
#  'conducted correctly',
#  'correctly Mr',
#  'Mr Darling',
#  'Darling knew',
#  'knew yet',
#  'yet sometimes',
#  'sometimes wondered',
#  'wondered uneasily',
#  'uneasily whether',
#  'whether neighbours',
#  'neighbours talked',
#  'talked He',
#  'He position',
#  'position city',
#  'city consider',
#  'consider Nana',
#  'Nana also',
#  'also troubled',
#  'troubled another',
#  'another way',
#  'way He',
#  'He sometimes',
#  'sometimes feeling',
#  'feeling admire',
#  'admire I',
#  'I know',
#  'know admires',
#  'admires tremendously',
#  'tremendously George',
#  'George Mrs',
#  'Mrs Darling',
#  'Darling would',
#  'would assure',
#  'assure would',
#  'would sign',
#  'sign children',
#  'children specially',
#  'specially nice',
#  'nice father',
#  'father Lovely',
#  'Lovely dances',
#  'dances followed',
#  'followed servant',
#  'servant Liza',
#  'Liza sometimes',
#  'sometimes allowed',
#  'allowed join',
#  'join Such',
#  'Such midget',
#  'midget looked',
#  'looked long',
#  'long skirt',
#  'skirt maid',
#  "maid 's",
#  "'s cap",
#  'cap though',
#  'though sworn',
#  'sworn engaged',
#  'engaged would',
#  'would never',
#  'never see',
#  'see ten',
#  'ten The',
#  'The gaiety',
#  'gaiety romps',
#  'romps And',
#  'And gayest',
#  'gayest Mrs',
#  'Mrs Darling',
#  'Darling would',
#  'would pirouette',
#  'pirouette wildly',
#  'wildly could',
#  'could see',
#  'see kiss',
#  'kiss dashed',
#  'dashed might',
#  'might got',
#  'got There',
#  'There never',
#  'never simpler',
#  'simpler happier',
#  'happier family',
#  'family coming',
#  'coming Peter',
#  'Peter Pan',
#  'Pan Mrs',
#  'Mrs Darling',
#  'Darling first',
#  'first heard',
#  'heard Peter',
#  'Peter tidying',
#  'tidying children',
#  "children 's",
#  "'s minds",
#  'minds It',
#  'It nightly',
#  'nightly custom',
#  'custom every',
#  'every good',
#  'good mother',
#  'mother children',
#  'children asleep',
#  'asleep rummage',
#  'rummage minds',
#  'minds put',
#  'put things',
#  'things straight',
#  'straight next',
#  'next morning',
#  'morning repacking',
#  'repacking proper',
#  'proper places',
#  'places many',
#  'many articles',
#  'articles wandered',
#  'wandered day',
#  'day If',
#  'If could',
#  'could keep',
#  'keep awake',
#  'awake course',
#  'course ca',
#  "ca n't",
#  "n't would",
#  'would see',
#  'see mother',
#  'mother would',
#  'would find',
#  'find interesting',
#  'interesting watch',
#  'watch It',
#  'It quite',
#  'quite like',
#  'like tidying',
#  'tidying drawers',
#  'drawers You',
#  'You would',
#  'would see',
#  'see knees',
#  'knees I',
#  'I expect',
#  'expect lingering',
#  'lingering humorously',
#  'humorously contents',
#  'contents wondering',
#  'wondering earth',
#  'earth picked',
#  'picked thing',
#  'thing making',
#  'making discoveries',
#  'discoveries sweet',
#  'sweet sweet',
#  'sweet pressing',
#  'pressing cheek',
#  'cheek nice',
#  'nice kitten',
#  'kitten hurriedly',
#  'hurriedly stowing',
#  'stowing sight',
#  'sight When',
#  'When wake',
#  'wake morning',
#  'morning naughtiness',
#  'naughtiness evil',
#  'evil passions',
#  'passions went',
#  'went bed',
#  'bed folded',
#  'folded small',
#  'small placed',
#  'placed bottom',
#  'bottom mind',
#  'mind top',
#  'top beautifully',
#  'beautifully aired',
#  'aired spread',
#  'spread prettier',
#  'prettier thoughts',
#  'thoughts ready',
#  'ready put',
#  'put I',
#  "I n't",
#  "n't know",
#  'know whether',
#  'whether ever',
#  'ever seen',
#  'seen map',
#  'map person',
#  "person 's",
#  "'s mind",
#  'mind Doctors',
#  'Doctors sometimes',
#  'sometimes draw',
#  'draw maps',
#  'maps parts',
#  'parts map',
#  'map become',
#  'become intensely',
#  'intensely interesting',
#  'interesting catch',
#  'catch trying',
#  'trying draw',
#  'draw map',
#  'map child',
#  "child 's",
#  "'s mind",
#  'mind confused',
#  'confused keeps',
#  'keeps going',
#  'going round',
#  'round time',
#  'time There',
#  'There zigzag',
#  'zigzag lines',
#  'lines like',
#  'like temperature',
#  'temperature card',
#  'card probably',
#  'probably roads',
#  'roads island',
#  'island Neverland',
#  'Neverland always',
#  'always less',
#  'less island',
#  'island astonishing',
#  'astonishing splashes',
#  'splashes colour',
#  'colour coral',
#  'coral reefs',
#  'reefs rakish-looking',
#  'rakish-looking craft',
#  'craft offing',
#  'offing savages',
#  'savages lonely',
#  'lonely lairs',
#  'lairs gnomes',
#  'gnomes mostly',
#  'mostly tailors',
#  'tailors caves',
#  'caves river',
#  'river runs',
#  'runs princes',
#  'princes six',
#  'six elder',
#  'elder brothers',
#  'brothers hut',
#  'hut fast',
#  'fast going',
#  'going decay',
#  'decay one',
#  'one small',
#  'small old',
#  'old lady',
#  'lady hooked',
#  'hooked nose',
#  'nose It',
#  'It would',
#  'would easy',
#  'easy map',
#  'map also',
#  'also first',
#  'first day',
#  'day school',
#  'school religion',
#  'religion fathers',
#  'fathers round',
#  'round pond',
#  'pond needle-work',
#  'needle-work murders',
#  'murders hangings',
#  'hangings verbs',
#  'verbs take',
#  'take dative',
#  'dative chocolate',
#  'chocolate pudding',
#  'pudding day',
#  'day getting',
#  'getting braces',
#  'braces say',
#  'say ninety-nine',
#  'ninety-nine three-pence',
#  'three-pence pulling',
#  'pulling tooth',
#  'tooth either',
#  'either part',
#  'part island',
#  'island another',
#  'another map',
#  'map showing',
#  'showing rather',
#  'rather confusing',
#  'confusing especially',
#  'especially nothing',
#  'nothing stand',
#  'stand still',
#  'still Of',
#  'Of course',
#  'course Neverlands',
#  'Neverlands vary',
#  'vary good',
#  'good deal',
#  'deal John',
#  "John 's",
#  "'s instance",
#  'instance lagoon',
#  'lagoon flamingoes',
#  'flamingoes flying',
#  'flying John',
#  'John shooting',
#  'shooting Michael',
#  'Michael small',
#  'small flamingo',
#  'flamingo lagoons',
#  'lagoons flying',
#  'flying John',
#  'John lived',
#  'lived boat',
#  'boat turned',
#  'turned upside',
#  'upside sands',
#  'sands Michael',
#  'Michael wigwam',
#  'wigwam Wendy',
#  'Wendy house',
#  'house leaves',
#  'leaves deftly',
#  'deftly sewn',
#  'sewn together',
#  'together John',
#  'John friends',
#  'friends Michael',
#  'Michael friends',
#  'friends night',
#  'night Wendy',
#  'Wendy pet',
#  'pet wolf',
#  'wolf forsaken',
#  'forsaken parents',
#  'parents whole',
#  'whole Neverlands',
#  'Neverlands family',
#  'family resemblance',
#  'resemblance stood',
#  'stood still',
#  'still row',
#  'row could',
#  'could say',
#  "say 's",
#  "'s nose",
#  'nose forth',
#  'forth On',
#  'On magic',
#  'magic shores',
#  'shores children',
#  'children play',
#  'play ever',
#  'ever beaching',
#  'beaching coracles',
#  'coracles We',
#  'We still',
#  'still hear',
#  'hear sound',
#  'sound surf',
#  'surf though',
#  'though shall',
#  'shall land',
#  'land Of',
#  'Of delectable',
#  'delectable islands',
#  'islands Neverland',
#  'Neverland snuggest',
#  'snuggest compact',
#  'compact large',
#  'large sprawly',
#  'sprawly know',
#  'know tedious',
#  'tedious distances',
#  'distances one',
#  'one adventure',
#  'adventure another',
#  'another nicely',
#  'nicely crammed',
#  'crammed When',
#  'When play',
#  'play day',
#  'day chairs',
#  'chairs table-cloth',
#  'table-cloth least',
#  'least alarming',
#  'alarming two',
#  'two minutes',
#  'minutes go',
#  'go sleep',
#  'sleep becomes',
#  ...]

# %% [markdown]
# 2. Next, please find out the frequency of each bigram, and print out the top 5 most frequent bigrams together with their frequencies.
#
# <font color="blue">(5 points)</font>

# %%
# ADD YOUR CODE HERE. You are free to split your code to multiple cells when necessary.

bigrams_freq = {}

for i in bigrams:
    if i not in bigrams_freq:
        bigrams_freq[i] = 1
    else:
        bigrams_freq[i] += 1

bigrams_freq
# Out:
# {'All children': 2,
#  'children except': 2,
#  'except one': 1,
#  'one grow': 1,
#  'grow They': 1,
#  'They soon': 1,
#  'soon know': 1,
#  'know grow': 1,
#  'grow way': 1,
#  'way Wendy': 3,
#  'Wendy knew': 3,
#  'knew One': 1,
#  'One day': 1,
#  'day two': 1,
#  'two years': 1,
#  'years old': 1,
#  'old playing': 1,
#  'playing garden': 1,
#  'garden plucked': 1,
#  'plucked another': 1,
#  'another flower': 1,
#  'flower ran': 1,
#  'ran mother': 1,
#  'mother I': 4,
#  'I suppose': 6,
#  'suppose must': 1,
#  'must looked': 1,
#  'looked rather': 2,
#  'rather delightful': 1,
#  'delightful Mrs': 1,
#  'Mrs Darling': 71,
#  'Darling put': 3,
#  'put hand': 2,
#  'hand heart': 1,
#  'heart cried': 1,
#  'cried Oh': 1,
#  'Oh ca': 2,
#  "ca n't": 27,
#  "n't remain": 1,
#  'remain like': 1,
#  'like ever': 2,
#  'ever This': 1,
#  'This passed': 1,
#  'passed subject': 1,
#  'subject henceforth': 1,
#  'henceforth Wendy': 1,
#  'knew must': 1,
#  'must grow': 1,
#  'grow You': 1,
#  'You always': 1,
#  'always know': 1,
#  'know two': 2,
#  'two Two': 1,
#  'Two beginning': 1,
#  'beginning end': 1,
#  'end Of': 1,
#  'Of course': 42,
#  'course lived': 1,
#  'lived 14': 1,
#  '14 Wendy': 1,
#  'Wendy came': 4,
#  'came mother': 1,
#  'mother chief': 1,
#  'chief one': 1,
#  'one She': 1,
#  'She lovely': 1,
#  'lovely lady': 1,
#  'lady romantic': 1,
#  'romantic mind': 2,
#  'mind sweet': 1,
#  'sweet mocking': 2,
#  'mocking mouth': 2,
#  'mouth Her': 1,
#  'Her romantic': 1,
#  'mind like': 1,
#  'like tiny': 1,
#  'tiny boxes': 1,
#  'boxes one': 1,
#  'one within': 1,
#  'within come': 1,
#  'come puzzling': 1,
#  'puzzling East': 1,
#  'East however': 1,
#  'however many': 2,
#  'many discover': 1,
#  'discover always': 1,
#  'always one': 1,
#  'one sweet': 1,
#  'mouth one': 3,
#  'one kiss': 1,
#  'kiss Wendy': 2,
#  'Wendy could': 4,
#  'could never': 3,
#  'never get': 1,
#  'get though': 1,
#  'though perfectly': 1,
#  'perfectly conspicuous': 1,
#  'conspicuous right-hand': 1,
#  'right-hand corner': 2,
#  'corner The': 1,
#  'The way': 3,
#  'way Mr': 1,
#  'Mr Darling': 39,
#  'Darling many': 1,
#  'many gentlemen': 1,
#  'gentlemen boys': 1,
#  'boys girl': 1,
#  'girl discovered': 1,
#  'discovered simultaneously': 1,
#  'simultaneously loved': 1,
#  'loved ran': 1,
#  'ran house': 1,
#  'house propose': 1,
#  'propose except': 1,
#  'except Mr': 1,
#  'Darling took': 1,
#  'took cab': 1,
#  'cab nipped': 1,
#  'nipped first': 1,
#  'first got': 1,
#  'got He': 1,
#  'He got': 1,
#  'got except': 1,
#  'except innermost': 1,
#  'innermost box': 1,
#  'box kiss': 1,
#  'kiss He': 2,
#  'He never': 2,
#  'never knew': 3,
#  'knew box': 1,
#  'box time': 1,
#  'time gave': 1,
#  'gave trying': 1,
#  'trying kiss': 1,
#  'Wendy thought': 1,
#  'thought Napoleon': 1,
#  'Napoleon could': 1,
#  'could got': 1,
#  'got I': 1,
#  'I picture': 1,
#  'picture trying': 1,
#  'trying going': 1,
#  'going passion': 1,
#  'passion slamming': 1,
#  'slamming door': 1,
#  'door Mr': 2,
#  'Darling used': 1,
#  'used boast': 1,
#  'boast Wendy': 1,
#  'Wendy mother': 3,
#  'mother loved': 1,
#  'loved respected': 1,
#  'respected He': 1,
#  'He one': 4,
#  'one deep': 1,
#  'deep ones': 1,
#  'ones know': 1,
#  'know stocks': 1,
#  'stocks shares': 3,
#  'shares Of': 1,
#  'course one': 1,
#  'one really': 1,
#  'really knows': 1,
#  'knows quite': 1,
#  'quite seemed': 1,
#  'seemed know': 1,
#  'know often': 1,
#  'often said': 3,
#  'said stocks': 1,
#  'shares way': 1,
#  'way would': 2,
#  'would made': 3,
#  'made woman': 1,
#  'woman respect': 1,
#  'respect Mrs': 1,
#  'Darling married': 1,
#  'married white': 2,
#  'white first': 1,
#  'first kept': 1,
#  'kept books': 1,
#  'books perfectly': 1,
#  'perfectly almost': 1,
#  'almost gleefully': 1,
#  'gleefully game': 1,
#  'game much': 1,
#  'much Brussels': 1,
#  'Brussels sprout': 1,
#  'sprout missing': 1,
#  'missing whole': 1,
#  'whole cauliflowers': 1,
#  'cauliflowers dropped': 1,
#  'dropped instead': 1,
#  'instead pictures': 1,
#  'pictures babies': 1,
#  'babies without': 1,
#  'without faces': 1,
#  'faces She': 1,
#  'She drew': 1,
#  'drew totting': 1,
#  'totting They': 1,
#  'They Mrs': 1,
#  "Darling 's": 6,
#  "'s guesses": 1,
#  'guesses Wendy': 1,
#  'came first': 1,
#  'first John': 1,
#  'John Michael': 28,
#  'Michael For': 1,
#  'For week': 1,
#  'week two': 1,
#  'two Wendy': 1,
#  'came doubtful': 1,
#  'doubtful whether': 1,
#  'whether would': 2,
#  'would able': 1,
#  'able keep': 1,
#  'keep another': 1,
#  'another mouth': 1,
#  'mouth feed': 1,
#  'feed Mr': 1,
#  'Darling frightfully': 2,
#  'frightfully proud': 1,
#  'proud honourable': 1,
#  'honourable sat': 1,
#  'sat edge': 1,
#  'edge Mrs': 1,
#  "'s bed": 1,
#  'bed holding': 1,
#  'holding hand': 2,
#  'hand calculating': 1,
#  'calculating expenses': 1,
#  'expenses looked': 1,
#  'looked imploringly': 1,
#  'imploringly She': 1,
#  'She wanted': 1,
#  'wanted risk': 1,
#  'risk come': 1,
#  'come might': 1,
#  'might way': 1,
#  'way way': 1,
#  'way pencil': 1,
#  'pencil piece': 1,
#  'piece paper': 3,
#  'paper confused': 1,
#  'confused suggestions': 1,
#  'suggestions begin': 1,
#  'begin beginning': 1,
#  'beginning Now': 1,
#  "Now n't": 1,
#  "n't interrupt": 1,
#  'interrupt would': 1,
#  'would beg': 1,
#  'beg I': 1,
#  'I one': 3,
#  'one pound': 2,
#  'pound seventeen': 1,
#  'seventeen two': 1,
#  'two six': 1,
#  'six office': 1,
#  'office I': 4,
#  'I cut': 2,
#  'cut coffee': 1,
#  'coffee office': 1,
#  'office say': 1,
#  'say ten': 1,
#  'ten shillings': 1,
#  'shillings making': 1,
#  'making two': 1,
#  'two nine': 1,
#  'nine six': 2,
#  'six eighteen': 1,
#  'eighteen three': 1,
#  'three makes': 1,
#  'makes three': 1,
#  'three nine': 1,
#  'nine seven': 5,
#  'seven five': 1,
#  'five naught': 1,
#  'naught naught': 1,
#  'naught cheque-book': 1,
#  'cheque-book makes': 1,
#  'makes eight': 1,
#  'eight nine': 1,
#  'nine seven—who': 1,
#  'seven—who moving': 1,
#  'moving —eight': 1,
#  '—eight nine': 1,
#  'seven dot': 1,
#  'dot carry': 1,
#  'carry seven—do': 1,
#  "seven—do n't": 1,
#  "n't speak": 1,
#  'speak own—and': 1,
#  'own—and pound': 1,
#  'pound lent': 1,
#  'lent man': 1,
#  'man came': 1,
#  'came door—quiet': 1,
#  'door—quiet child—dot': 1,
#  'child—dot carry': 1,
#  'carry child—there': 1,
#  "child—there 've": 1,
#  "'ve done": 1,
#  'done —did': 1,
#  '—did I': 1,
#  'I say': 12,
#  'say nine': 1,
#  'nine nine': 3,
#  'seven yes': 1,
#  'yes I': 1,
#  'I said': 8,
#  'said nine': 1,
#  'seven question': 1,
#  'question try': 1,
#  'try year': 1,
#  'year nine': 1,
#  'seven Of': 1,
#  'course George': 1,
#  'George cried': 2,
#  'cried But': 1,
#  'But prejudiced': 1,
#  'prejudiced Wendy': 1,
#  "Wendy 's": 24,
#  "'s favour": 1,
#  'favour really': 1,
#  'really grander': 1,
#  'grander character': 1,
#  'character two': 1,
#  'two Remember': 1,
#  'Remember mumps': 1,
#  'mumps warned': 1,
#  'warned almost': 1,
#  'almost threateningly': 1,
#  'threateningly went': 1,
#  'went Mumps': 1,
#  'Mumps one': 1,
#  'pound I': 1,
#  'I put': 4,
#  'put I': 2,
#  'I daresay': 2,
#  'daresay like': 1,
#  'like thirty': 1,
#  'thirty shillings—do': 1,
#  "shillings—do n't": 1,
#  "n't speak—measles": 1,
#  'speak—measles one': 1,
#  'one five': 1,
#  'five German': 1,
#  'German measles': 1,
#  'measles half': 1,
#  'half guinea': 1,
#  'guinea makes': 1,
#  'makes two': 1,
#  'two fifteen': 1,
#  'fifteen six—do': 1,
#  "six—do n't": 1,
#  "n't waggle": 1,
#  'waggle finger—whooping-cough': 1,
#  'finger—whooping-cough say': 1,
#  'say fifteen': 1,
#  'fifteen shillings': 1,
#  'shillings —and': 1,
#  '—and went': 1,
#  'went added': 1,
#  'added differently': 1,
#  'differently time': 1,
#  'time last': 1,
#  'last Wendy': 1,
#  'Wendy got': 1,
#  'got mumps': 1,
#  'mumps reduced': 1,
#  'reduced twelve': 1,
#  'twelve six': 1,
#  'six two': 1,
#  'two kinds': 1,
#  'kinds measles': 1,
#  'measles treated': 1,
#  'treated one': 1,
#  'one There': 1,
#  'There excitement': 1,
#  'excitement John': 1,
#  'Michael even': 1,
#  'even narrower': 1,
#  'narrower squeak': 1,
#  'squeak kept': 1,
#  'kept soon': 1,
#  'soon might': 1,
#  'might seen': 1,
#  'seen three': 1,
#  'three going': 1,
#  'going row': 1,
#  'row Miss': 1,
#  'Miss Fulsom': 2,
#  "Fulsom 's": 2,
#  "'s Kindergarten": 1,
#  'Kindergarten school': 1,
#  'school accompanied': 1,
#  'accompanied nurse': 1,
#  'nurse Mrs': 1,
#  'Darling loved': 1,
#  'loved everything': 2,
#  'everything Mr': 1,
#  'Darling passion': 1,
#  'passion exactly': 1,
#  'exactly like': 2,
#  'like neighbours': 1,
#  'neighbours course': 1,
#  'course nurse': 1,
#  'nurse As': 1,
#  'As poor': 1,
#  'poor owing': 1,
#  'owing amount': 1,
#  'amount milk': 1,
#  'milk children': 2,
#  'children drank': 1,
#  'drank nurse': 1,
#  'nurse prim': 1,
#  'prim Newfoundland': 1,
#  'Newfoundland dog': 1,
#  'dog called': 1,
#  'called Nana': 2,
#  'Nana belonged': 1,
#  'belonged one': 1,
#  'one particular': 1,
#  'particular Darlings': 1,
#  'Darlings engaged': 1,
#  'engaged She': 1,
#  'She always': 2,
#  'always thought': 1,
#  'thought children': 1,
#  'children important': 1,
#  'important however': 1,
#  'however Darlings': 1,
#  'Darlings become': 1,
#  'become acquainted': 1,
#  'acquainted Kensington': 1,
#  'Kensington Gardens': 3,
#  'Gardens spent': 1,
#  'spent spare': 1,
#  'spare time': 1,
#  'time peeping': 1,
#  'peeping perambulators': 1,
#  'perambulators much': 1,
#  'much hated': 1,
#  'hated careless': 1,
#  'careless nursemaids': 1,
#  'nursemaids followed': 1,
#  'followed homes': 1,
#  'homes complained': 1,
#  'complained mistresses': 1,
#  'mistresses She': 1,
#  'She proved': 1,
#  'proved quite': 1,
#  'quite treasure': 1,
#  'treasure nurse': 1,
#  'nurse How': 1,
#  'How thorough': 1,
#  'thorough bath-time': 1,
#  'bath-time moment': 1,
#  'moment night': 1,
#  'night one': 3,
#  'one charges': 1,
#  'charges made': 1,
#  'made slightest': 1,
#  'slightest cry': 1,
#  'cry Of': 1,
#  'course kennel': 1,
#  'kennel nursery': 1,
#  'nursery She': 1,
#  'She genius': 1,
#  'genius knowing': 1,
#  'knowing cough': 1,
#  'cough thing': 1,
#  'thing patience': 1,
#  'patience needs': 1,
#  'needs stocking': 1,
#  'stocking around': 1,
#  'around throat': 1,
#  'throat She': 1,
#  'She believed': 2,
#  'believed last': 2,
#  'last day': 1,
#  'day old-fashioned': 1,
#  'old-fashioned remedies': 1,
#  'remedies like': 1,
#  'like rhubarb': 1,
#  'rhubarb leaf': 1,
#  'leaf made': 1,
#  'made sounds': 1,
#  'sounds contempt': 1,
#  'contempt new-fangled': 1,
#  'new-fangled talk': 1,
#  'talk germs': 1,
#  'germs It': 1,
#  'It lesson': 1,
#  'lesson propriety': 1,
#  'propriety see': 1,
#  'see escorting': 1,
#  'escorting children': 1,
#  'children school': 1,
#  'school walking': 1,
#  'walking sedately': 1,
#  'sedately side': 1,
#  'side well': 1,
#  'well behaved': 1,
#  'behaved butting': 1,
#  'butting back': 1,
#  'back line': 1,
#  'line strayed': 1,
#  'strayed On': 1,
#  "On John's": 1,
#  "John's footer": 1,
#  'footer days': 1,
#  'days never': 1,
#  'never forgot': 1,
#  'forgot sweater': 1,
#  'sweater usually': 1,
#  'usually carried': 1,
#  'carried umbrella': 1,
#  'umbrella mouth': 1,
#  'mouth case': 1,
#  'case rain': 1,
#  'rain There': 1,
#  'There room': 1,
#  'room basement': 1,
#  'basement Miss': 1,
#  "'s school": 1,
#  'school nurses': 1,
#  'nurses wait': 1,
#  'wait They': 1,
#  'They sat': 2,
#  'sat forms': 1,
#  'forms Nana': 1,
#  'Nana lay': 1,
#  'lay floor': 1,
#  'floor difference': 1,
#  'difference They': 1,
#  'They affected': 1,
#  'affected ignore': 1,
#  'ignore inferior': 1,
#  'inferior social': 1,
#  'social status': 1,
#  'status despised': 1,
#  'despised light': 1,
#  'light talk': 1,
#  'talk She': 1,
#  'She resented': 1,
#  'resented visits': 1,
#  'visits nursery': 1,
#  'nursery Mrs': 1,
#  "'s friends": 2,
#  'friends come': 1,
#  'come first': 1,
#  'first whipped': 1,
#  'whipped Michael': 1,
#  "Michael 's": 9,
#  "'s pinafore": 1,
#  'pinafore put': 1,
#  'put one': 1,
#  'one blue': 1,
#  'blue braiding': 1,
#  'braiding smoothed': 1,
#  'smoothed Wendy': 1,
#  'Wendy made': 1,
#  'made dash': 1,
#  'dash John': 1,
#  "John 's": 7,
#  "'s hair": 1,
#  'hair No': 1,
#  'No nursery': 1,
#  'nursery could': 1,
#  'could possibly': 1,
#  'possibly conducted': 1,
#  'conducted correctly': 1,
#  'correctly Mr': 1,
#  'Darling knew': 2,
#  'knew yet': 1,
#  'yet sometimes': 1,
#  'sometimes wondered': 1,
#  'wondered uneasily': 1,
#  'uneasily whether': 1,
#  'whether neighbours': 1,
#  'neighbours talked': 1,
#  'talked He': 1,
#  'He position': 1,
#  'position city': 1,
#  'city consider': 1,
#  'consider Nana': 1,
#  'Nana also': 2,
#  'also troubled': 1,
#  'troubled another': 1,
#  'another way': 1,
#  'way He': 1,
#  'He sometimes': 1,
#  'sometimes feeling': 1,
#  'feeling admire': 1,
#  'admire I': 1,
#  'I know': 13,
#  'know admires': 1,
#  'admires tremendously': 1,
#  'tremendously George': 1,
#  'George Mrs': 4,
#  'Darling would': 6,
#  'would assure': 1,
#  'assure would': 1,
#  'would sign': 1,
#  'sign children': 1,
#  'children specially': 1,
#  'specially nice': 1,
#  'nice father': 1,
#  'father Lovely': 1,
#  'Lovely dances': 1,
#  'dances followed': 1,
#  'followed servant': 1,
#  'servant Liza': 1,
#  'Liza sometimes': 1,
#  'sometimes allowed': 1,
#  'allowed join': 1,
#  'join Such': 1,
#  'Such midget': 1,
#  'midget looked': 1,
#  'looked long': 1,
#  'long skirt': 1,
#  'skirt maid': 1,
#  "maid 's": 1,
#  "'s cap": 1,
#  'cap though': 1,
#  'though sworn': 1,
#  'sworn engaged': 1,
#  'engaged would': 1,
#  'would never': 4,
#  'never see': 2,
#  'see ten': 1,
#  'ten The': 1,
#  'The gaiety': 1,
#  'gaiety romps': 1,
#  'romps And': 1,
#  'And gayest': 1,
#  'gayest Mrs': 1,
#  'would pirouette': 1,
#  'pirouette wildly': 1,
#  'wildly could': 1,
#  'could see': 6,
#  'see kiss': 1,
#  'kiss dashed': 1,
#  'dashed might': 1,
#  'might got': 1,
#  'got There': 1,
#  'There never': 1,
#  'never simpler': 1,
#  'simpler happier': 1,
#  'happier family': 1,
#  'family coming': 1,
#  'coming Peter': 3,
#  'Peter Pan': 18,
#  'Pan Mrs': 1,
#  'Darling first': 1,
#  'first heard': 1,
#  'heard Peter': 4,
#  'Peter tidying': 1,
#  'tidying children': 1,
#  "children 's": 4,
#  "'s minds": 3,
#  'minds It': 1,
#  'It nightly': 1,
#  'nightly custom': 1,
#  'custom every': 1,
#  'every good': 1,
#  'good mother': 1,
#  'mother children': 1,
#  'children asleep': 2,
#  'asleep rummage': 1,
#  'rummage minds': 1,
#  'minds put': 1,
#  'put things': 1,
#  'things straight': 1,
#  'straight next': 1,
#  'next morning': 1,
#  'morning repacking': 1,
#  'repacking proper': 1,
#  'proper places': 1,
#  'places many': 1,
#  'many articles': 1,
#  'articles wandered': 1,
#  'wandered day': 1,
#  'day If': 1,
#  'If could': 1,
#  'could keep': 1,
#  'keep awake': 1,
#  'awake course': 1,
#  'course ca': 1,
#  "n't would": 1,
#  'would see': 2,
#  'see mother': 1,
#  'mother would': 4,
#  'would find': 2,
#  'find interesting': 1,
#  'interesting watch': 1,
#  'watch It': 1,
#  'It quite': 4,
#  'quite like': 2,
#  'like tidying': 1,
#  'tidying drawers': 1,
#  'drawers You': 1,
#  'You would': 2,
#  'see knees': 1,
#  'knees I': 1,
#  'I expect': 3,
#  'expect lingering': 1,
#  'lingering humorously': 1,
#  'humorously contents': 1,
#  'contents wondering': 1,
#  'wondering earth': 1,
#  'earth picked': 1,
#  'picked thing': 1,
#  'thing making': 1,
#  'making discoveries': 1,
#  'discoveries sweet': 1,
#  'sweet sweet': 1,
#  'sweet pressing': 1,
#  'pressing cheek': 1,
#  'cheek nice': 1,
#  'nice kitten': 1,
#  'kitten hurriedly': 1,
#  'hurriedly stowing': 1,
#  'stowing sight': 1,
#  'sight When': 1,
#  'When wake': 1,
#  'wake morning': 1,
#  'morning naughtiness': 1,
#  'naughtiness evil': 1,
#  'evil passions': 1,
#  'passions went': 1,
#  'went bed': 3,
#  'bed folded': 1,
#  'folded small': 1,
#  'small placed': 1,
#  'placed bottom': 1,
#  'bottom mind': 1,
#  'mind top': 1,
#  'top beautifully': 1,
#  'beautifully aired': 1,
#  'aired spread': 1,
#  'spread prettier': 1,
#  'prettier thoughts': 1,
#  'thoughts ready': 1,
#  'ready put': 1,
#  "I n't": 33,
#  "n't know": 15,
#  'know whether': 3,
#  'whether ever': 1,
#  'ever seen': 3,
#  'seen map': 1,
#  'map person': 1,
#  "person 's": 1,
#  "'s mind": 2,
#  'mind Doctors': 1,
#  'Doctors sometimes': 1,
#  'sometimes draw': 1,
#  'draw maps': 1,
#  'maps parts': 1,
#  'parts map': 1,
#  'map become': 1,
#  'become intensely': 1,
#  'intensely interesting': 1,
#  'interesting catch': 1,
#  'catch trying': 1,
#  'trying draw': 1,
#  'draw map': 1,
#  'map child': 1,
#  "child 's": 1,
#  'mind confused': 1,
#  'confused keeps': 1,
#  'keeps going': 1,
#  'going round': 3,
#  'round time': 2,
#  'time There': 2,
#  'There zigzag': 1,
#  'zigzag lines': 1,
#  'lines like': 1,
#  'like temperature': 1,
#  'temperature card': 1,
#  'card probably': 1,
#  'probably roads': 1,
#  'roads island': 1,
#  'island Neverland': 1,
#  'Neverland always': 2,
#  'always less': 1,
#  'less island': 1,
#  'island astonishing': 1,
#  'astonishing splashes': 1,
#  'splashes colour': 1,
#  'colour coral': 1,
#  'coral reefs': 1,
#  'reefs rakish-looking': 1,
#  'rakish-looking craft': 2,
#  'craft offing': 1,
#  'offing savages': 1,
#  'savages lonely': 1,
#  'lonely lairs': 1,
#  'lairs gnomes': 1,
#  'gnomes mostly': 1,
#  'mostly tailors': 1,
#  'tailors caves': 1,
#  'caves river': 1,
#  'river runs': 1,
#  'runs princes': 1,
#  'princes six': 1,
#  'six elder': 1,
#  'elder brothers': 1,
#  'brothers hut': 1,
#  'hut fast': 1,
#  'fast going': 1,
#  'going decay': 1,
#  'decay one': 1,
#  'one small': 1,
#  'small old': 1,
#  'old lady': 4,
#  'lady hooked': 1,
#  'hooked nose': 1,
#  'nose It': 1,
#  'It would': 5,
#  'would easy': 1,
#  'easy map': 1,
#  'map also': 1,
#  'also first': 1,
#  'first day': 1,
#  'day school': 1,
#  'school religion': 1,
#  'religion fathers': 1,
#  'fathers round': 1,
#  'round pond': 1,
#  'pond needle-work': 1,
#  'needle-work murders': 1,
#  'murders hangings': 1,
#  'hangings verbs': 1,
#  'verbs take': 1,
#  'take dative': 1,
#  'dative chocolate': 1,
#  'chocolate pudding': 1,
#  'pudding day': 1,
#  'day getting': 1,
#  'getting braces': 1,
#  'braces say': 1,
#  'say ninety-nine': 1,
#  'ninety-nine three-pence': 1,
#  'three-pence pulling': 1,
#  'pulling tooth': 1,
#  'tooth either': 1,
#  'either part': 1,
#  'part island': 1,
#  'island another': 1,
#  'another map': 1,
#  'map showing': 1,
#  'showing rather': 1,
#  'rather confusing': 1,
#  'confusing especially': 1,
#  'especially nothing': 1,
#  'nothing stand': 1,
#  'stand still': 3,
#  'still Of': 1,
#  'course Neverlands': 1,
#  'Neverlands vary': 1,
#  'vary good': 1,
#  'good deal': 2,
#  'deal John': 1,
#  "'s instance": 1,
#  'instance lagoon': 1,
#  'lagoon flamingoes': 1,
#  'flamingoes flying': 1,
#  'flying John': 2,
#  'John shooting': 1,
#  'shooting Michael': 1,
#  'Michael small': 1,
#  'small flamingo': 1,
#  'flamingo lagoons': 1,
#  'lagoons flying': 1,
#  'John lived': 1,
#  'lived boat': 1,
#  'boat turned': 1,
#  'turned upside': 1,
#  'upside sands': 1,
#  'sands Michael': 1,
#  'Michael wigwam': 1,
#  'wigwam Wendy': 1,
#  'Wendy house': 1,
#  'house leaves': 1,
#  'leaves deftly': 1,
#  'deftly sewn': 1,
#  'sewn together': 1,
#  'together John': 1,
#  'John friends': 1,
#  'friends Michael': 1,
#  'Michael friends': 1,
#  'friends night': 1,
#  'night Wendy': 2,
#  'Wendy pet': 1,
#  'pet wolf': 2,
#  'wolf forsaken': 1,
#  'forsaken parents': 1,
#  'parents whole': 1,
#  'whole Neverlands': 1,
#  'Neverlands family': 1,
#  'family resemblance': 1,
#  'resemblance stood': 1,
#  'stood still': 3,
#  'still row': 1,
#  'row could': 1,
#  'could say': 1,
#  "say 's": 1,
#  "'s nose": 2,
#  'nose forth': 1,
#  'forth On': 1,
#  'On magic': 1,
#  'magic shores': 2,
#  'shores children': 1,
#  'children play': 1,
#  'play ever': 1,
#  'ever beaching': 1,
#  'beaching coracles': 1,
#  'coracles We': 1,
#  'We still': 2,
#  'still hear': 1,
#  'hear sound': 1,
#  'sound surf': 1,
#  'surf though': 1,
#  'though shall': 1,
#  'shall land': 1,
#  'land Of': 1,
#  'Of delectable': 1,
#  'delectable islands': 1,
#  'islands Neverland': 1,
#  'Neverland snuggest': 1,
#  'snuggest compact': 1,
#  'compact large': 1,
#  'large sprawly': 1,
#  'sprawly know': 1,
#  'know tedious': 1,
#  'tedious distances': 1,
#  'distances one': 1,
#  'one adventure': 1,
#  'adventure another': 1,
#  'another nicely': 1,
#  'nicely crammed': 1,
#  'crammed When': 1,
#  'When play': 1,
#  'play day': 1,
#  'day chairs': 1,
#  'chairs table-cloth': 1,
#  'table-cloth least': 1,
#  'least alarming': 1,
#  'alarming two': 1,
#  'two minutes': 2,
#  'minutes go': 1,
#  'go sleep': 1,
#  'sleep becomes': 1,
#  'becomes real': 1,
#  'real That': 1,
#  'That night-lights': 1,
#  'night-lights Occasionally': 1,
#  'Occasionally travels': 1,
#  'travels children': 1,
#  'minds Mrs': 1,
#  'Darling found': 1,
#  'found things': 1,
#  'things could': 1,
#  'could understand': 4,
#  'understand quite': 1,
#  'quite perplexing': 1,
#  'perplexing word': 1,
#  'word Peter': 2,
#  'Peter She': 2,
#  'She knew': 2,
#  'knew Peter': 3,
#  'Peter yet': 1,
#  'yet John': 1,
#  'minds Wendy': 1,
#  "'s began": 1,
#  'began scrawled': 1,
#  'scrawled The': 1,
#  'The name': 1,
#  'name stood': 1,
#  'stood bolder': 1,
#  'bolder letters': 1,
#  'letters words': 1,
#  'words Mrs': 1,
#  'Darling gazed': 1,
#  'gazed felt': 1,
#  'felt oddly': 1,
#  'oddly cocky': 1,
#  'cocky appearance': 1,
#  'appearance Yes': 1,
#  'Yes rather': 1,
#  'rather cocky': 1,
#  'cocky Wendy': 1,
#  'Wendy admitted': 2,
#  'admitted regret': 1,
#  'regret Her': 1,
#  'Her mother': 1,
#  'mother questioning': 1,
#  ...}

# %%
bigrams_freq = sorted(bigrams_freq.items(), key=lambda x: x[1], reverse=True)

for i in bigrams_freq[:5]:
    print(i)
# Out:
# ('Mrs Darling', 71)
# ('Of course', 42)
# ('Mr Darling', 39)
# ("I n't", 33)
# ('Wendy said', 30)

# %% [markdown]
# ## Additional Criterion: Programming Style
#
# Please comment your code sufficiently. <font color="blue">(5 points)</font>

# %% [markdown]
# ---**END**---
